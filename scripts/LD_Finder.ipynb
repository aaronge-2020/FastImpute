# %% [markdown]
# # Use LD Proxy API to find the relevant positions for each of the PRS313 SNPs

# %%
import requests
import pandas as pd
import os
import io


# API key
api_key = "ac16be4ad92d"

# Base URL for LDProxy API
base_url = "https://ldlink.nih.gov/LDlinkRest/ldproxy"

population = "ALL"

window = 500000

r2_threshold = 0.01

# Read the chromosome positions from the text file
with open("../positions/locations.txt", "r") as file:
    positions = file.read().strip().split("\n")

# Create a folder to store the CSV files
output_folder = "../ld_variants"
os.makedirs(output_folder, exist_ok=True)

# Iterate over each position
for position in positions:
    # Extract chromosome and position from the line
    chrom, pos = position.strip().split()
    
    # Construct the API request URL
    url = f"{base_url}?var={chrom}:{pos}&pop={population}&r2_d=r2&window={window}&genome_build=grch37&token={api_key}"
    
    # Send the API request
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
            # Create a StringIO object from the data
            data_io = io.StringIO(response.text)

            # Read the data into a DataFrame using read_csv
            df = pd.read_csv(data_io, sep='\\t')
            
            # # Filter variants with high LD scores (e.g., R2 >= 0.8)
            # high_ld_variants = df[df["R2"].astype(float) >= 0.8]
            
            # Generate a unique filename for the CSV file
            output_file = os.path.join(output_folder, f"{chrom}_{pos}.csv")
            
            # Save the high LD variants to a CSV file
            df.to_csv(output_file, index=False)
            
            print(f"Saved high LD variants for {chrom}:{pos} to {output_file}")
    else:
        print(f"Failed to retrieve data for {chrom}:{pos}. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 36
#      33 url = f"{base_url}?var={chrom}:{pos}&pop={population}&r2_d=r2&window={window}&genome_build=grch37&token={api_key}"
#      35 # Send the API request
# ---> 36 response = requests.get(url)
#      38 # Check if the request was successful
#      39 if response.status_code == 200:
#      40         # Create a StringIO object from the data
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
chrom, pos = positions[0].strip().split()

# Construct the API request URL
url = f"{base_url}?var={chrom}:{pos}&pop={population}&r2_d=r2&window={window}&genome_build=grch37&token={api_key}"

# Send the API request
response = requests.get(url)

# %%
# Remove the leading single quote
data = response.text

# Create a StringIO object from the data
data_io = io.StringIO(data)

# Read the data into a DataFrame using read_csv
df = pd.read_csv(data_io, sep='\\t')
df
# Out:
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_16385/1453726256.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(data_io, sep='\\t')
#         RS_Number           Coord Alleles     MAF  Distance  Dprime      R2  \
# 0        rs612683  chr1:100880328   (A/T)  0.4004         0  1.0000  1.0000
# 1      rs12568038  chr1:100879914   (C/T)  0.3415      -414  0.8908  0.6162
# 2      rs12564838  chr1:100883188   (A/G)  0.3496      2860  0.8609  0.5968
# 3       rs7517704  chr1:100885419   (A/G)  0.3494      5091  0.8609  0.5962
# 4      rs12760924  chr1:100898600   (A/T)  0.3546     18272  0.8357  0.5748
# ...           ...             ...     ...     ...       ...     ...     ...
# 1214  rs111334083  chr1:100617033   (G/A)  0.0212   -263295  0.8351  0.0101
# 1215  rs141366089  chr1:100950426   (-/T)  0.0575     70098  0.4970  0.0101
# 1216   rs10493930  chr1:101079706   (T/C)  0.0833    199378  0.4070  0.0100
# 1217   rs57411954  chr1:100712556  (AC/-)  0.0276   -167772  0.7285  0.0100
# 1218    rs7518386  chr1:101055617   (T/C)  0.0260    175289  0.7502  0.0100
#
#      Correlated_Alleles  FORGEdb RegulomeDB Function
# 0               A=A,T=T      9.0         2b      NaN
# 1               A=C,T=T      6.0          7      NaN
# 2               A=A,T=G      6.0          5      NaN
# 3               A=A,T=G      6.0          6      NaN
# 4               A=A,T=T      6.0          6      NaN
# ...                 ...      ...        ...      ...
# 1214                NaN      7.0          5      NaN
# 1215                NaN      NaN          .      NaN
# 1216                NaN      6.0          5      NaN
# 1217                NaN      NaN          .      NaN
# 1218                NaN      4.0         3a      NaN
#
# [1219 rows x 11 columns]

# %% [markdown]
# # Find overlap b/w 23AndMe and LD

# %%
# Separate files in one directory into multiple folders based on chromosome number. The files are named chromosomeNumber_chromosomePosition.csv

directory = "../ld_variants"

# Create a folder to store the CSV files
output_folder = "../ld_variants"
os.makedirs(output_folder, exist_ok=True)

# Iterate over each file in the directory

for filename in os.listdir(directory):
    # Check if the file is a CSV file
    if filename.endswith(".csv"):
        # Extract the chromosome number and position from the filename
        chrom, pos = filename.split("_")
        pos = pos.split(".")[0]
        
        # Create a folder for the chromosome number
        chrom_folder = os.path.join(output_folder, "chr" + chrom)
        os.makedirs(chrom_folder, exist_ok=True)
        
        # Move the file to the chromosome folder
        src = os.path.join(directory, filename)
        dest = os.path.join(chrom_folder, filename)
        os.rename(src, dest)
        
        print(f"Moved {filename} to {chrom_folder}")
# Out:
# Moved 6_152432902.csv to ../ld_variants/chr6
# Moved 5_79180995.csv to ../ld_variants/chr5
# Moved 7_25569548.csv to ../ld_variants/chr7
# Moved 6_152055978.csv to ../ld_variants/chr6
# Moved 5_44508264.csv to ../ld_variants/chr5
# Moved 12_14413931.csv to ../ld_variants/chr12
# Moved 4_106069013.csv to ../ld_variants/chr4
# Moved 3_55970777.csv to ../ld_variants/chr3
# Moved 3_59373745.csv to ../ld_variants/chr3
# Moved 1_88156923.csv to ../ld_variants/chr1
# Moved 6_16399557.csv to ../ld_variants/chr6
# Moved 12_115796577.csv to ../ld_variants/chr12
# Moved 5_131640536.csv to ../ld_variants/chr5
# Moved 2_218292158.csv to ../ld_variants/chr2
# Moved 10_38523626.csv to ../ld_variants/chr10
# Moved 1_120257110.csv to ../ld_variants/chr1
# Moved 8_106358620.csv to ../ld_variants/chr8
# Moved 22_46283297.csv to ../ld_variants/chr22
# Moved 3_141112859.csv to ../ld_variants/chr3
# Moved 16_6963972.csv to ../ld_variants/chr16
# Moved 5_71965007.csv to ../ld_variants/chr5
# Moved 8_143669254.csv to ../ld_variants/chr8
# Moved 22_39343916.csv to ../ld_variants/chr22
# Moved 5_52679539.csv to ../ld_variants/chr5
# Moved 22_38583315.csv to ../ld_variants/chr22
# Moved 10_123340107.csv to ../ld_variants/chr10
# Moved 22_40904707.csv to ../ld_variants/chr22
# Moved 11_111696440.csv to ../ld_variants/chr11
# Moved 5_32579616.csv to ../ld_variants/chr5
# Moved 15_66630569.csv to ../ld_variants/chr15
# Moved 1_114445880.csv to ../ld_variants/chr1
# Moved 1_88428199.csv to ../ld_variants/chr1
# Moved 16_23007047.csv to ../ld_variants/chr16
# Moved 5_44619502.csv to ../ld_variants/chr5
# Moved 22_19766137.csv to ../ld_variants/chr22
# Moved 6_152023191.csv to ../ld_variants/chr6
# Moved 15_100905819.csv to ../ld_variants/chr15
# Moved 7_91459189.csv to ../ld_variants/chr7
# Moved 6_82263549.csv to ../ld_variants/chr6
# Moved 3_99403877.csv to ../ld_variants/chr3
# Moved 2_217920769.csv to ../ld_variants/chr2
# Moved 8_76333056.csv to ../ld_variants/chr8
# Moved 12_115835836.csv to ../ld_variants/chr12
# Moved 10_22861490.csv to ../ld_variants/chr10
# Moved 1_202184600.csv to ../ld_variants/chr1
# Moved 5_55662540.csv to ../ld_variants/chr5
# Moved 8_124571581.csv to ../ld_variants/chr8
# Moved 8_170692.csv to ../ld_variants/chr8
# Moved 10_123349324.csv to ../ld_variants/chr10
# Moved 4_38784633.csv to ../ld_variants/chr4
# Moved 11_122966626.csv to ../ld_variants/chr11
# Moved 6_152022664.csv to ../ld_variants/chr6
# Moved 4_175842495.csv to ../ld_variants/chr4
# Moved 15_67457698.csv to ../ld_variants/chr15
# Moved 10_123095209.csv to ../ld_variants/chr10
# Moved 15_46680811.csv to ../ld_variants/chr15
# Moved 12_120832146.csv to ../ld_variants/chr12
# Moved 1_121280613.csv to ../ld_variants/chr1
# Moved 8_76230943.csv to ../ld_variants/chr8
# Moved 20_52296849.csv to ../ld_variants/chr20
# Moved 1_118141492.csv to ../ld_variants/chr1
# Moved 1_168171052.csv to ../ld_variants/chr1
# Moved 22_43433100.csv to ../ld_variants/chr22
# Moved 11_69331418.csv to ../ld_variants/chr11
# Moved 12_103097887.csv to ../ld_variants/chr12
# Moved 11_1895708.csv to ../ld_variants/chr11
# Moved 5_77155397.csv to ../ld_variants/chr5
# Moved 3_172285237.csv to ../ld_variants/chr3
# Moved 5_73234583.csv to ../ld_variants/chr5
# Moved 2_172974566.csv to ../ld_variants/chr2
# Moved 22_45319953.csv to ../ld_variants/chr22
# Moved 2_88358825.csv to ../ld_variants/chr2
# Moved 12_96027759.csv to ../ld_variants/chr12
# Moved 18_29981526.csv to ../ld_variants/chr18
# Moved 5_345109.csv to ../ld_variants/chr5
# Moved 19_18569492.csv to ../ld_variants/chr19
# Moved 1_110198129.csv to ../ld_variants/chr1
# Moved 9_98362587.csv to ../ld_variants/chr9
# Moved 5_122478676.csv to ../ld_variants/chr5
# Moved 5_2777029.csv to ../ld_variants/chr5
# Moved 19_46166073.csv to ../ld_variants/chr19
# Moved 3_27388664.csv to ../ld_variants/chr3
# Moved 2_202204741.csv to ../ld_variants/chr2
# Moved 3_4742251.csv to ../ld_variants/chr3
# Moved 6_18783140.csv to ../ld_variants/chr6
# Moved 7_98005235.csv to ../ld_variants/chr7
# Moved 16_53861592.csv to ../ld_variants/chr16
# Moved 18_42888797.csv to ../ld_variants/chr18
# Moved 13_73806982.csv to ../ld_variants/chr13
# Moved 8_117209548.csv to ../ld_variants/chr8
# Moved 10_13892298.csv to ../ld_variants/chr10
# Moved 4_151218296.csv to ../ld_variants/chr4
# Moved 6_87803819.csv to ../ld_variants/chr6
# Moved 1_220671050.csv to ../ld_variants/chr1
# Moved 7_28869017.csv to ../ld_variants/chr7
# Moved 16_87086492.csv to ../ld_variants/chr16
# Moved 11_803017.csv to ../ld_variants/chr11
# Moved 12_85004551.csv to ../ld_variants/chr12
# Moved 1_46670206.csv to ../ld_variants/chr1
# Moved 13_32839990.csv to ../ld_variants/chr13
# Moved 2_174212910.csv to ../ld_variants/chr2
# Moved 11_433617.csv to ../ld_variants/chr11
# Moved 4_89240476.csv to ../ld_variants/chr4
# Moved 11_46318032.csv to ../ld_variants/chr11
# Moved 10_5794652.csv to ../ld_variants/chr10
# Moved 8_128213561.csv to ../ld_variants/chr8
# Moved 6_20537845.csv to ../ld_variants/chr6
# Moved 15_91512267.csv to ../ld_variants/chr15
# Moved 2_121246568.csv to ../ld_variants/chr2
# Moved 9_6880263.csv to ../ld_variants/chr9
# Moved 1_41389220.csv to ../ld_variants/chr1
# Moved 1_208076291.csv to ../ld_variants/chr1
# Moved 12_111600134.csv to ../ld_variants/chr12
# Moved 12_28149568.csv to ../ld_variants/chr12
# Moved 17_43212339.csv to ../ld_variants/chr17
# Moved 5_56045081.csv to ../ld_variants/chr5
# Moved 10_115128491.csv to ../ld_variants/chr10
# Moved 2_29615233.csv to ../ld_variants/chr2
# Moved 16_4008542.csv to ../ld_variants/chr16
# Moved 9_110885479.csv to ../ld_variants/chr9
# Moved 5_122705244.csv to ../ld_variants/chr5
# Moved 17_53209774.csv to ../ld_variants/chr17
# Moved 12_29140260.csv to ../ld_variants/chr12
# Moved 18_24337424.csv to ../ld_variants/chr18
# Moved 11_42844441.csv to ../ld_variants/chr11
# Moved 8_124739913.csv to ../ld_variants/chr8
# Moved 8_29509616.csv to ../ld_variants/chr8
# Moved 14_105213978.csv to ../ld_variants/chr14
# Moved 17_44283858.csv to ../ld_variants/chr17
# Moved 16_54682064.csv to ../ld_variants/chr16
# Moved 14_37228504.csv to ../ld_variants/chr14
# Moved 5_1353077.csv to ../ld_variants/chr5
# Moved 15_50694306.csv to ../ld_variants/chr15
# Moved 1_51467096.csv to ../ld_variants/chr1
# Moved 4_143467195.csv to ../ld_variants/chr4
# Moved 5_81512947.csv to ../ld_variants/chr5
# Moved 18_24125857.csv to ../ld_variants/chr18
# Moved 14_93070286.csv to ../ld_variants/chr14
# Moved 2_10138983.csv to ../ld_variants/chr2
# Moved 11_69330983.csv to ../ld_variants/chr11
# Moved 11_65572431.csv to ../ld_variants/chr11
# Moved 4_187503758.csv to ../ld_variants/chr4
# Moved 7_55192256.csv to ../ld_variants/chr7
# Moved 8_128372172.csv to ../ld_variants/chr8
# Moved 1_100880328.csv to ../ld_variants/chr1
# Moved 16_52599188.csv to ../ld_variants/chr16
# Moved 11_108267402.csv to ../ld_variants/chr11
# Moved 7_144048902.csv to ../ld_variants/chr7
# Moved 1_149906413.csv to ../ld_variants/chr1
# Moved 2_39699510.csv to ../ld_variants/chr2
# Moved 8_23447496.csv to ../ld_variants/chr8
# Moved 22_29203724.csv to ../ld_variants/chr22
# Moved 8_102483100.csv to ../ld_variants/chr8
# Moved 10_22032942.csv to ../ld_variants/chr10
# Moved 11_116727936.csv to ../ld_variants/chr11
# Moved 11_129243417.csv to ../ld_variants/chr11
# Moved 1_18807339.csv to ../ld_variants/chr1
# Moved 17_40485239.csv to ../ld_variants/chr17
# Moved 12_57146069.csv to ../ld_variants/chr12
# Moved 12_293626.csv to ../ld_variants/chr12
# Moved 11_129461016.csv to ../ld_variants/chr11
# Moved 3_27353716.csv to ../ld_variants/chr3
# Moved 1_7917076.csv to ../ld_variants/chr1
# Moved 8_120862186.csv to ../ld_variants/chr8
# Moved 4_175847436.csv to ../ld_variants/chr4
# Moved 16_80648296.csv to ../ld_variants/chr16
# Moved 16_52538825.csv to ../ld_variants/chr16
# Moved 17_77781725.csv to ../ld_variants/chr17
# Moved 2_25129473.csv to ../ld_variants/chr2
# Moved 14_37128564.csv to ../ld_variants/chr14
# Moved 19_44283031.csv to ../ld_variants/chr19
# Moved 3_29294845.csv to ../ld_variants/chr3
# Moved 5_176134882.csv to ../ld_variants/chr5
# Moved 5_58241712.csv to ../ld_variants/chr5
# Moved 6_85912194.csv to ../ld_variants/chr6
# Moved 11_103614438.csv to ../ld_variants/chr11
# Moved 8_124563705.csv to ../ld_variants/chr8
# Moved 6_151949806.csv to ../ld_variants/chr6
# Moved 20_41613706.csv to ../ld_variants/chr20
# Moved 20_11379842.csv to ../ld_variants/chr20
# Moved 6_169006947.csv to ../ld_variants/chr6
# Moved 16_10706580.csv to ../ld_variants/chr16
# Moved 11_18664241.csv to ../ld_variants/chr11
# Moved 1_217053815.csv to ../ld_variants/chr1
# Moved 9_110837176.csv to ../ld_variants/chr9
# Moved 7_101552440.csv to ../ld_variants/chr7
# Moved 1_145604302.csv to ../ld_variants/chr1
# Moved 2_121058254.csv to ../ld_variants/chr2
# Moved 9_21964882.csv to ../ld_variants/chr9
# Moved 2_241388857.csv to ../ld_variants/chr2
# Moved 6_13713366.csv to ../ld_variants/chr6
# Moved 7_99948655.csv to ../ld_variants/chr7
# Moved 18_24518050.csv to ../ld_variants/chr18
# Moved 12_70798355.csv to ../ld_variants/chr12
# Moved 9_36928288.csv to ../ld_variants/chr9
# Moved 5_90789470.csv to ../ld_variants/chr5
# Moved 1_203770448.csv to ../ld_variants/chr1
# Moved 21_16566350.csv to ../ld_variants/chr21
# Moved 13_73960952.csv to ../ld_variants/chr13
# Moved 10_64299890.csv to ../ld_variants/chr10
# Moved 7_139943702.csv to ../ld_variants/chr7
# Moved 11_69328130.csv to ../ld_variants/chr11
# Moved 18_11696613.csv to ../ld_variants/chr18
# Moved 10_80886726.csv to ../ld_variants/chr10
# Moved 5_44649944.csv to ../ld_variants/chr5
# Moved 17_40127060.csv to ../ld_variants/chr17
# Moved 2_121159205.csv to ../ld_variants/chr2
# Moved 21_47762932.csv to ../ld_variants/chr21
# Moved 8_76378165.csv to ../ld_variants/chr8
# Moved 1_10566215.csv to ../ld_variants/chr1
# Moved 18_25407513.csv to ../ld_variants/chr18
# Moved 7_94113799.csv to ../ld_variants/chr7
# Moved 3_30684907.csv to ../ld_variants/chr3
# Moved 3_46888198.csv to ../ld_variants/chr3
# Moved 7_130674481.csv to ../ld_variants/chr7
# Moved 22_29135543.csv to ../ld_variants/chr22
# Moved 13_32972626.csv to ../ld_variants/chr13
# Moved 10_123340431.csv to ../ld_variants/chr10
# Moved 5_132407058.csv to ../ld_variants/chr5
# Moved 14_91841069.csv to ../ld_variants/chr14
# Moved 4_126752992.csv to ../ld_variants/chr4
# Moved 8_128370949.csv to ../ld_variants/chr8
# Moved 6_21923810.csv to ../ld_variants/chr6
# Moved 9_110303808.csv to ../ld_variants/chr9
# Moved 5_1296255.csv to ../ld_variants/chr5
# Moved 9_129424719.csv to ../ld_variants/chr9
# Moved 5_56023083.csv to ../ld_variants/chr5
# Moved 9_119313486.csv to ../ld_variants/chr9
# Moved 10_80851257.csv to ../ld_variants/chr10
# Moved 9_110849525.csv to ../ld_variants/chr9
# Moved 16_4106788.csv to ../ld_variants/chr16
# Moved 5_44706498.csv to ../ld_variants/chr5
# Moved 22_29121087.csv to ../ld_variants/chr22
# Moved 10_22477776.csv to ../ld_variants/chr10
# Moved 12_28174817.csv to ../ld_variants/chr12
# Moved 6_43227141.csv to ../ld_variants/chr6
# Moved 17_29168077.csv to ../ld_variants/chr17
# Moved 9_136146597.csv to ../ld_variants/chr9
# Moved 1_242034263.csv to ../ld_variants/chr1
# Moved 9_87782211.csv to ../ld_variants/chr9
# Moved 7_21940960.csv to ../ld_variants/chr7
# Moved 11_65553492.csv to ../ld_variants/chr11
# Moved 17_39251123.csv to ../ld_variants/chr17
# Moved 5_104300273.csv to ../ld_variants/chr5
# Moved 2_217955896.csv to ../ld_variants/chr2
# Moved 19_13249921.csv to ../ld_variants/chr19
# Moved 11_44368892.csv to ../ld_variants/chr11
# Moved 10_95292187.csv to ../ld_variants/chr10
# Moved 17_40744470.csv to ../ld_variants/chr17
# Moved 16_85145977.csv to ../ld_variants/chr16
# Moved 6_151955914.csv to ../ld_variants/chr6
# Moved 3_71620370.csv to ../ld_variants/chr3
# Moved 16_53809123.csv to ../ld_variants/chr16
# Moved 6_170332621.csv to ../ld_variants/chr6
# Moved 6_149595505.csv to ../ld_variants/chr6
# Moved 7_102481842.csv to ../ld_variants/chr7
# Moved 5_16231194.csv to ../ld_variants/chr5
# Moved 14_68660428.csv to ../ld_variants/chr14
# Moved 3_49709912.csv to ../ld_variants/chr3
# Moved 4_92594859.csv to ../ld_variants/chr4
# Moved 10_71335574.csv to ../ld_variants/chr10
# Moved 1_41380440.csv to ../ld_variants/chr1
# Moved 21_16364756.csv to ../ld_variants/chr21
# Moved 13_43501356.csv to ../ld_variants/chr13
# Moved 8_36858483.csv to ../ld_variants/chr8
# Moved 8_17787610.csv to ../ld_variants/chr8
# Moved 2_192381934.csv to ../ld_variants/chr2
# Moved 9_22041998.csv to ../ld_variants/chr9
# Moved 6_27425644.csv to ../ld_variants/chr6
# Moved 19_19517054.csv to ../ld_variants/chr19
# Moved 21_16574455.csv to ../ld_variants/chr21
# Moved 10_64819996.csv to ../ld_variants/chr10
# Moved 12_83064195.csv to ../ld_variants/chr12
# Moved 4_84370124.csv to ../ld_variants/chr4
# Moved 19_17393925.csv to ../ld_variants/chr19
# Moved 3_189774456.csv to ../ld_variants/chr3
# Moved 5_1279790.csv to ../ld_variants/chr5
# Moved 2_121089731.csv to ../ld_variants/chr2
# Moved 10_114777670.csv to ../ld_variants/chr10
# Moved 7_130656911.csv to ../ld_variants/chr7
# Moved 3_63887449.csv to ../ld_variants/chr3
# Moved 2_70172587.csv to ../ld_variants/chr2
# Moved 16_53861139.csv to ../ld_variants/chr16
# Moved 2_19315675.csv to ../ld_variants/chr2
# Moved 12_115108136.csv to ../ld_variants/chr12
# Moved 18_20634253.csv to ../ld_variants/chr18
# Moved 20_5948227.csv to ../ld_variants/chr20
# Moved 1_217220574.csv to ../ld_variants/chr1
# Moved 5_173358154.csv to ../ld_variants/chr5
# Moved 3_87037543.csv to ../ld_variants/chr3
# Moved 14_68979835.csv to ../ld_variants/chr14
# Moved 2_29179452.csv to ../ld_variants/chr2
# Moved 1_155556971.csv to ../ld_variants/chr1
# Moved 19_55816678.csv to ../ld_variants/chr19
# Moved 1_201437832.csv to ../ld_variants/chr1
# Moved 18_42411803.csv to ../ld_variants/chr18
# Moved 5_169591460.csv to ../ld_variants/chr5
# Moved 1_204502514.csv to ../ld_variants/chr1
# Moved 22_29551872.csv to ../ld_variants/chr22
# Moved 2_218714845.csv to ../ld_variants/chr2
# Moved 8_23663653.csv to ../ld_variants/chr8
# Moved 8_129199566.csv to ../ld_variants/chr8
# Moved 9_110837073.csv to ../ld_variants/chr9
# Moved 15_75750383.csv to ../ld_variants/chr15
# Moved 5_44853593.csv to ../ld_variants/chr5
# Moved 5_158244083.csv to ../ld_variants/chr5
# Moved 5_56042972.csv to ../ld_variants/chr5
# Moved 14_91751788.csv to ../ld_variants/chr14
# Moved 6_130341728.csv to ../ld_variants/chr6
# Moved 1_172328767.csv to ../ld_variants/chr1
# Moved 1_121287994.csv to ../ld_variants/chr1
# Moved 5_55965167.csv to ../ld_variants/chr5
# Moved 12_28347382.csv to ../ld_variants/chr12

# %%
import os
import pandas as pd
import re

def extract_coord_alleles(col_name):
    match = re.search(r'chr(\d+)_(\d+)_([ACGT])_([ACGT])', col_name)
    if match:
        chr_num, position, ref, alt = match.groups()
        return f'chr{chr_num}:{position}', f'({ref}/{alt})'
    return None, None

# Create an empty list to store the matching variants across all chromosomes
matching_variants_all = []

# Iterate over each chromosome folder
for chrom_folder in os.listdir(output_folder):
    # Check if the folder is a chromosome folder
    if chrom_folder.startswith("chr"):
        # Extract the chromosome number
        chrom = chrom_folder[3:]
        files_folder = os.path.join(output_folder, chrom_folder)
        
        # Load the training data for the chromosome
        training_data = pd.read_parquet(f"../Final_training_data/23AndMe_PRS313_merged_chr{chrom}.parquet")
        
        # Create empty lists to store the matching columns and variants for the chromosome
        matching_columns = []
        matching_variants_chrom = []
        
        # Read all the files in the folder
        for filename in os.listdir(files_folder):
            # Check if the file is a CSV file
            if filename.endswith(".csv"):
                # Load the variants for the file
                variants = pd.read_csv(os.path.join(files_folder, filename))
                
                # Find the matching columns in the training data
                for column in training_data.columns:
                    coord, alleles = extract_coord_alleles(column)
                    if coord is not None and alleles is not None:
                        mask = (variants['Coord'] == coord) & (variants['Alleles'] == alleles)
                        if mask.any():
                            matching_columns.append(column)
                            matching_variants_chrom.append(variants[mask])
                            print(f"Found matching variant for {variants[mask]}")
                

        # Get the matching columns from the training data
        matching_data = training_data[matching_columns]
        
        # Save the matching data for the chromosome
        matching_data.to_parquet(f"../Final_training_data/23AndMe_PRS313_merged_chr{chrom}_matching.parquet")
        
        # Concatenate the matching variants for the chromosome into a single dataframe
        matching_variants_chrom_df = pd.concat(matching_variants_chrom, ignore_index=True)
        
        # Append the matching variants for the chromosome to the overall list
        matching_variants_all.append(matching_variants_chrom_df)

        print(f"Processed chromosome {chrom}")
        print(f"Found {len(matching_columns)} matching columns")
        print(f"Found {len(matching_variants_chrom_df)} matching variants")

# Concatenate the matching variants from all chromosomes into a single dataframe
matching_variants_all_df = pd.concat(matching_variants_all, ignore_index=True)

# Save the dataframe with matching variants across all chromosomes
matching_variants_all_df.to_csv("../Final_training_data/23AndMe_matching_variants.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 41
#      39 coord, alleles = extract_coord_alleles(column)
#      40 if coord is not None and alleles is not None:
# ---> 41     mask = (variants['Coord'] == coord) & (variants['Alleles'] == alleles)
#      42     if mask.any():
#      43         matching_columns.append(column)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:5810, in Series._logical_method(self, other, op)
#    5807 lvalues = self._values
#    5808 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5810 res_values = ops.logical_op(lvalues, rvalues, op)
#    5811 return self._construct_result(res_values, name=res_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:450, in logical_op(left, right, op)
#     448     is_other_int_dtype = rvalues.dtype.kind in "iu"
#     449     if not is_other_int_dtype:
# --> 450         rvalues = fill_bool(rvalues, lvalues)
#     452 else:
#     453     # i.e. scalar
#     454     is_other_int_dtype = lib.is_integer(rvalues)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:422, in logical_op.<locals>.fill_bool(x, left)
#     419         x[mask] = False
#     421 if left is None or left.dtype.kind == "b":
# --> 422     x = x.astype(bool)
#     423 return x
#
# KeyboardInterrupt:

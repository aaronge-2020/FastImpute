# %%
import pandas as pd
import glob
import os

def read_vcf_header(file_path):
    """Reads the VCF file header (column names) and returns it."""
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('#CHROM'):
                return line.strip().split('\t')
    return []

def extract_snp_data(file_path, header):
    """Extracts SNP data from a VCF file."""
    snp_data = []
    with open(file_path, 'r') as file:
        for line in file:
            if not line.startswith('#'):
                fields = line.strip().split('\t')
                chrom, pos, ref, alt = fields[0], fields[1], fields[3], fields[4]
                snp_id = f"chr{chrom}_{pos}_{ref}_{alt}"
                genotype_data = fields[9:]  # Genotype data starts from the 10th column
                snp_data.append((snp_id, genotype_data))
    return snp_data

def process_vcf_files(directory):
    """Processes all VCF files in the specified directory."""
    vcf_files = glob.glob(os.path.join(directory, '*.vcf'))
    all_snp_data = []
    patient_ids = None
    
    for file_path in vcf_files:
        if patient_ids is None:
            patient_ids = read_vcf_header(file_path)[9:]  # Assuming the first 9 columns are standard VCF columns
        snp_data = extract_snp_data(file_path, patient_ids)
        all_snp_data.extend(snp_data)

    # Convert the collected SNP data to a DataFrame
    data_dict = {snp_id: genotypes for snp_id, genotypes in all_snp_data}
    df = pd.DataFrame(data_dict, index=patient_ids).transpose()
    
    return df

# %%
df_bcftools.max()
# Out:
# Series([], dtype: float64)

# %%
# Replace 'your_directory_path' with the path to your directory containing the VCF files
directory_path = '../../Data/bcftools_results/'
df_bcftools = process_vcf_files(directory_path).transpose()


# If you want to save this DataFrame to a CSV file for further analysis
df_bcftools.to_csv('concatenated_snps.csv')

# %%
# List number of files in the directory
vcf_files = glob.glob(os.path.join(directory_path, '*.vcf'))
print(f"Number of VCF files: {len(vcf_files)}")
# Out:
# Number of VCF files: 0

# %%
# Get all chromosome 10 SNPs
chrom_10_snps = df_bcftools.columns[df_bcftools.columns.str.startswith('chr22_')]
print(chrom_10_snps)
print(len(chrom_10_snps))
# Out:
# Index(['chr22_19707371', 'chr22_19766137', 'chr22_29114293', 'chr22_29121087',
#        'chr22_29135543', 'chr22_29203724', 'chr22_29551872', 'chr22_38583315',
#        'chr22_39343916', 'chr22_40904707', 'chr22_43433100', 'chr22_45319942',
#        'chr22_45319953', 'chr22_46283297'],
#       dtype='object')
# 14

# %%
# Replace 'your_directory_path' with the path to your directory containing the TSV files
directory_path = '../Grep_tsv_files/'

import os

def extract_alleles(directory):
    
    files = {}
    for filename in os.listdir(directory):
        alleles = []

        if filename.endswith(".vcf"):
            filepath = os.path.join(directory, filename)
            with open(filepath, "r") as file:
                line = file.readline().strip()
                fields = line.split("\t")
                
                if len(fields) >= 10:
                    genotypes = fields[9:]
                    for genotype in genotypes:
                        
                        alleles.append(genotype.replace("|", ""))
            files["chr" + filename.split(".")[0]] = alleles
    
    return pd.DataFrame(files).T

df_grep = extract_alleles(directory_path)

# %%
# Select a SNP ID that is present in both dataframes
snp_id = 'chr22_40904707'

# Get the genotypes for the selected SNP from both dataframes
genotypes_bcftools = df_bcftools.loc[snp_id].values
genotypes_plink = df_plink.loc[snp_id].values
genotypes_grep = df_grep.loc[snp_id].values


# Replace the '/' and '|' characters in the genotypes
genotypes_bcftools = [genotype.replace('/', '').replace('|', '') for genotype in genotypes_bcftools]
genotypes_plink = [genotype.replace('/', '').replace('|', '') for genotype in genotypes_plink]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chr22_40904707'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       2 snp_id = 'chr22_40904707'
#       4 # Get the genotypes for the selected SNP from both dataframes
# ----> 5 genotypes_bcftools = df_bcftools.loc[snp_id].values
#       6 genotypes_plink = df_plink.loc[snp_id].values
#       7 genotypes_grep = df_grep.loc[snp_id].values
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'chr22_40904707'

# %%
# Check if the genotypes are equal
genotypes_equal = all(g1 == g2 for g1, g2 in zip(genotypes_bcftools, genotypes_plink))

if genotypes_equal:
    print(f"The genotypes for SNP {snp_id} are equal in both dataframes.")
else:
    print(f"The genotypes for SNP {snp_id} are not equal in both dataframes.")
    # Get the particular patients that are not equal
    counter = 0
    for patient_id, g1, g2 in zip(df_bcftools.columns, genotypes_bcftools, genotypes_plink):
        if g1 != g2:
            print(f"Patient {patient_id}: BCFTOOLS - {g1}, PLINK - {g2}")
            counter += 1
    print(f"Total number of patients with different genotypes: {counter}")
# Out:
# The genotypes for SNP chr22_40904707 are not equal in both dataframes.
# Patient HG00119: BCFTOOLS - 10, PLINK - 01
# Patient HG00132: BCFTOOLS - 10, PLINK - 01
# Patient HG00136: BCFTOOLS - 10, PLINK - 01
# Patient HG00158: BCFTOOLS - 10, PLINK - 01
# Patient HG00171: BCFTOOLS - 10, PLINK - 01
# Patient HG00186: BCFTOOLS - 10, PLINK - 01
# Patient HG00251: BCFTOOLS - 10, PLINK - 01
# Patient HG00255: BCFTOOLS - 10, PLINK - 01
# Patient HG00267: BCFTOOLS - 10, PLINK - 01
# Patient HG00271: BCFTOOLS - 10, PLINK - 01
# Patient HG00274: BCFTOOLS - 10, PLINK - 01
# Patient HG00280: BCFTOOLS - 10, PLINK - 01
# Patient HG00281: BCFTOOLS - 10, PLINK - 01
# Patient HG00304: BCFTOOLS - 10, PLINK - 01
# Patient HG00306: BCFTOOLS - 10, PLINK - 01
# Patient HG00309: BCFTOOLS - 10, PLINK - 01
# Patient HG00313: BCFTOOLS - 10, PLINK - 01
# Patient HG00326: BCFTOOLS - 10, PLINK - 01
# Patient HG00327: BCFTOOLS - 10, PLINK - 01
# Patient HG00341: BCFTOOLS - 10, PLINK - 01
# Patient HG00344: BCFTOOLS - 10, PLINK - 01
# Patient HG00357: BCFTOOLS - 10, PLINK - 01
# Patient HG00360: BCFTOOLS - 10, PLINK - 01
# Patient HG00364: BCFTOOLS - 10, PLINK - 01
# Patient HG00367: BCFTOOLS - 10, PLINK - 01
# Patient HG00379: BCFTOOLS - 10, PLINK - 01
# Patient HG00380: BCFTOOLS - 10, PLINK - 01
# Patient HG00382: BCFTOOLS - 10, PLINK - 01
# Patient HG00384: BCFTOOLS - 10, PLINK - 01
# Patient HG00403: BCFTOOLS - 10, PLINK - 01
# Patient HG00410: BCFTOOLS - 10, PLINK - 01
# Patient HG00421: BCFTOOLS - 10, PLINK - 01
# Patient HG00458: BCFTOOLS - 10, PLINK - 01
# Patient HG00476: BCFTOOLS - 10, PLINK - 01
# Patient HG00478: BCFTOOLS - 10, PLINK - 01
# Patient HG00531: BCFTOOLS - 10, PLINK - 01
# Patient HG00556: BCFTOOLS - 10, PLINK - 01
# Patient HG00557: BCFTOOLS - 10, PLINK - 01
# Patient HG00583: BCFTOOLS - 10, PLINK - 01
# Patient HG00599: BCFTOOLS - 10, PLINK - 01
# Patient HG00613: BCFTOOLS - 10, PLINK - 01
# Patient HG00625: BCFTOOLS - 10, PLINK - 01
# Patient HG00628: BCFTOOLS - 10, PLINK - 01
# Patient HG00634: BCFTOOLS - 10, PLINK - 01
# Patient HG00650: BCFTOOLS - 10, PLINK - 01
# Patient HG00653: BCFTOOLS - 10, PLINK - 01
# Patient HG00654: BCFTOOLS - 10, PLINK - 01
# Patient HG00663: BCFTOOLS - 10, PLINK - 01
# Patient HG00683: BCFTOOLS - 10, PLINK - 01
# Patient HG00684: BCFTOOLS - 10, PLINK - 01
# Patient HG00690: BCFTOOLS - 10, PLINK - 01
# Patient HG00693: BCFTOOLS - 10, PLINK - 01
# Patient HG00699: BCFTOOLS - 10, PLINK - 01
# Patient HG00844: BCFTOOLS - 10, PLINK - 01
# Patient HG01048: BCFTOOLS - 10, PLINK - 01
# Patient HG01049: BCFTOOLS - 10, PLINK - 01
# Patient HG01122: BCFTOOLS - 10, PLINK - 01
# Patient HG01134: BCFTOOLS - 10, PLINK - 01
# Patient HG01136: BCFTOOLS - 10, PLINK - 01
# Patient HG01142: BCFTOOLS - 10, PLINK - 01
# Patient HG01187: BCFTOOLS - 10, PLINK - 01
# Patient HG01251: BCFTOOLS - 10, PLINK - 01
# Patient HG01348: BCFTOOLS - 10, PLINK - 01
# Patient HG01356: BCFTOOLS - 10, PLINK - 01
# Patient HG01438: BCFTOOLS - 10, PLINK - 01
# Patient HG01440: BCFTOOLS - 10, PLINK - 01
# Patient HG01455: BCFTOOLS - 10, PLINK - 01
# Patient HG01500: BCFTOOLS - 10, PLINK - 01
# Patient HG01503: BCFTOOLS - 10, PLINK - 01
# Patient HG01605: BCFTOOLS - 10, PLINK - 01
# Patient HG01617: BCFTOOLS - 10, PLINK - 01
# Patient HG01624: BCFTOOLS - 10, PLINK - 01
# Patient HG01630: BCFTOOLS - 10, PLINK - 01
# Patient HG01697: BCFTOOLS - 10, PLINK - 01
# Patient HG01707: BCFTOOLS - 10, PLINK - 01
# Patient HG01768: BCFTOOLS - 10, PLINK - 01
# Patient HG01796: BCFTOOLS - 10, PLINK - 01
# Patient HG01801: BCFTOOLS - 10, PLINK - 01
# Patient HG01810: BCFTOOLS - 10, PLINK - 01
# Patient HG01812: BCFTOOLS - 10, PLINK - 01
# Patient HG01841: BCFTOOLS - 10, PLINK - 01
# Patient HG01849: BCFTOOLS - 10, PLINK - 01
# Patient HG01878: BCFTOOLS - 10, PLINK - 01
# Patient HG01880: BCFTOOLS - 10, PLINK - 01
# Patient HG01882: BCFTOOLS - 10, PLINK - 01
# Patient HG01926: BCFTOOLS - 10, PLINK - 01
# Patient HG01933: BCFTOOLS - 10, PLINK - 01
# Patient HG01950: BCFTOOLS - 10, PLINK - 01
# Patient HG02010: BCFTOOLS - 10, PLINK - 01
# Patient HG02019: BCFTOOLS - 10, PLINK - 01
# Patient HG02023: BCFTOOLS - 10, PLINK - 01
# Patient HG02032: BCFTOOLS - 10, PLINK - 01
# Patient HG02035: BCFTOOLS - 10, PLINK - 01
# Patient HG02061: BCFTOOLS - 10, PLINK - 01
# Patient HG02064: BCFTOOLS - 10, PLINK - 01
# Patient HG02067: BCFTOOLS - 10, PLINK - 01
# Patient HG02073: BCFTOOLS - 10, PLINK - 01
# Patient HG02082: BCFTOOLS - 10, PLINK - 01
# Patient HG02086: BCFTOOLS - 10, PLINK - 01
# Patient HG02087: BCFTOOLS - 10, PLINK - 01
# Patient HG02088: BCFTOOLS - 10, PLINK - 01
# Patient HG02107: BCFTOOLS - 10, PLINK - 01
# Patient HG02108: BCFTOOLS - 10, PLINK - 01
# Patient HG02131: BCFTOOLS - 10, PLINK - 01
# Patient HG02144: BCFTOOLS - 10, PLINK - 01
# Patient HG02151: BCFTOOLS - 10, PLINK - 01
# Patient HG02180: BCFTOOLS - 10, PLINK - 01
# Patient HG02238: BCFTOOLS - 10, PLINK - 01
# Patient HG02275: BCFTOOLS - 10, PLINK - 01
# Patient HG02278: BCFTOOLS - 10, PLINK - 01
# Patient HG02304: BCFTOOLS - 10, PLINK - 01
# Patient HG02312: BCFTOOLS - 10, PLINK - 01
# Patient HG02314: BCFTOOLS - 10, PLINK - 01
# Patient HG02323: BCFTOOLS - 10, PLINK - 01
# Patient HG02325: BCFTOOLS - 10, PLINK - 01
# Patient HG02332: BCFTOOLS - 10, PLINK - 01
# Patient HG02348: BCFTOOLS - 10, PLINK - 01
# Patient HG02391: BCFTOOLS - 10, PLINK - 01
# Patient HG02420: BCFTOOLS - 10, PLINK - 01
# Patient HG02445: BCFTOOLS - 10, PLINK - 01
# Patient HG02450: BCFTOOLS - 10, PLINK - 01
# Patient HG02461: BCFTOOLS - 10, PLINK - 01
# Patient HG02477: BCFTOOLS - 10, PLINK - 01
# Patient HG02491: BCFTOOLS - 10, PLINK - 01
# Patient HG02494: BCFTOOLS - 10, PLINK - 01
# Patient HG02574: BCFTOOLS - 10, PLINK - 01
# Patient HG02582: BCFTOOLS - 10, PLINK - 01
# Patient HG02646: BCFTOOLS - 10, PLINK - 01
# Patient HG02702: BCFTOOLS - 10, PLINK - 01
# Patient HG02703: BCFTOOLS - 10, PLINK - 01
# Patient HG02721: BCFTOOLS - 10, PLINK - 01
# Patient HG02775: BCFTOOLS - 10, PLINK - 01
# Patient HG02784: BCFTOOLS - 10, PLINK - 01
# Patient HG02790: BCFTOOLS - 10, PLINK - 01
# Patient HG02808: BCFTOOLS - 10, PLINK - 01
# Patient HG02836: BCFTOOLS - 10, PLINK - 01
# Patient HG02860: BCFTOOLS - 10, PLINK - 01
# Patient HG02878: BCFTOOLS - 10, PLINK - 01
# Patient HG02923: BCFTOOLS - 10, PLINK - 01
# Patient HG02977: BCFTOOLS - 10, PLINK - 01
# Patient HG02981: BCFTOOLS - 10, PLINK - 01
# Patient HG03048: BCFTOOLS - 10, PLINK - 01
# Patient HG03063: BCFTOOLS - 10, PLINK - 01
# Patient HG03084: BCFTOOLS - 10, PLINK - 01
# Patient HG03085: BCFTOOLS - 10, PLINK - 01
# Patient HG03108: BCFTOOLS - 10, PLINK - 01
# Patient HG03111: BCFTOOLS - 10, PLINK - 01
# Patient HG03237: BCFTOOLS - 10, PLINK - 01
# Patient HG03267: BCFTOOLS - 10, PLINK - 01
# Patient HG03367: BCFTOOLS - 10, PLINK - 01
# Patient HG03385: BCFTOOLS - 10, PLINK - 01
# Patient HG03437: BCFTOOLS - 10, PLINK - 01
# Patient HG03461: BCFTOOLS - 10, PLINK - 01
# Patient HG03491: BCFTOOLS - 10, PLINK - 01
# Patient HG03575: BCFTOOLS - 10, PLINK - 01
# Patient HG03595: BCFTOOLS - 10, PLINK - 01
# Patient HG03598: BCFTOOLS - 10, PLINK - 01
# Patient HG03603: BCFTOOLS - 10, PLINK - 01
# Patient HG03625: BCFTOOLS - 10, PLINK - 01
# Patient HG03629: BCFTOOLS - 10, PLINK - 01
# Patient HG03644: BCFTOOLS - 10, PLINK - 01
# Patient HG03673: BCFTOOLS - 10, PLINK - 01
# Patient HG03702: BCFTOOLS - 10, PLINK - 01
# Patient HG03706: BCFTOOLS - 10, PLINK - 01
# Patient HG03709: BCFTOOLS - 10, PLINK - 01
# Patient HG03730: BCFTOOLS - 10, PLINK - 01
# Patient HG03767: BCFTOOLS - 10, PLINK - 01
# Patient HG03773: BCFTOOLS - 10, PLINK - 01
# Patient HG03781: BCFTOOLS - 10, PLINK - 01
# Patient HG03897: BCFTOOLS - 10, PLINK - 01
# Patient HG03900: BCFTOOLS - 10, PLINK - 01
# Patient HG03902: BCFTOOLS - 10, PLINK - 01
# Patient HG03922: BCFTOOLS - 10, PLINK - 01
# Patient HG03945: BCFTOOLS - 10, PLINK - 01
# Patient HG03951: BCFTOOLS - 10, PLINK - 01
# Patient HG03989: BCFTOOLS - 10, PLINK - 01
# Patient HG03991: BCFTOOLS - 10, PLINK - 01
# Patient HG04014: BCFTOOLS - 10, PLINK - 01
# Patient HG04018: BCFTOOLS - 10, PLINK - 01
# Patient HG04033: BCFTOOLS - 10, PLINK - 01
# Patient HG04039: BCFTOOLS - 10, PLINK - 01
# Patient HG04171: BCFTOOLS - 10, PLINK - 01
# Patient HG04186: BCFTOOLS - 10, PLINK - 01
# Patient HG04194: BCFTOOLS - 10, PLINK - 01
# Patient HG04195: BCFTOOLS - 10, PLINK - 01
# Patient HG04235: BCFTOOLS - 10, PLINK - 01
# Patient NA06984: BCFTOOLS - 10, PLINK - 01
# Patient NA11992: BCFTOOLS - 10, PLINK - 01
# Patient NA12154: BCFTOOLS - 10, PLINK - 01
# Patient NA12249: BCFTOOLS - 10, PLINK - 01
# Patient NA12348: BCFTOOLS - 10, PLINK - 01
# Patient NA12413: BCFTOOLS - 10, PLINK - 01
# Patient NA12750: BCFTOOLS - 10, PLINK - 01
# Patient NA12762: BCFTOOLS - 10, PLINK - 01
# Patient NA12878: BCFTOOLS - 10, PLINK - 01
# Patient NA12890: BCFTOOLS - 10, PLINK - 01
# Patient NA18486: BCFTOOLS - 10, PLINK - 01
# Patient NA18498: BCFTOOLS - 10, PLINK - 01
# Patient NA18504: BCFTOOLS - 10, PLINK - 01
# Patient NA18511: BCFTOOLS - 10, PLINK - 01
# Patient NA18526: BCFTOOLS - 10, PLINK - 01
# Patient NA18542: BCFTOOLS - 10, PLINK - 01
# Patient NA18544: BCFTOOLS - 10, PLINK - 01
# Patient NA18546: BCFTOOLS - 10, PLINK - 01
# Patient NA18563: BCFTOOLS - 10, PLINK - 01
# Patient NA18567: BCFTOOLS - 10, PLINK - 01
# Patient NA18579: BCFTOOLS - 10, PLINK - 01
# Patient NA18593: BCFTOOLS - 10, PLINK - 01
# Patient NA18599: BCFTOOLS - 10, PLINK - 01
# Patient NA18605: BCFTOOLS - 10, PLINK - 01
# Patient NA18606: BCFTOOLS - 10, PLINK - 01
# Patient NA18614: BCFTOOLS - 10, PLINK - 01
# Patient NA18615: BCFTOOLS - 10, PLINK - 01
# Patient NA18617: BCFTOOLS - 10, PLINK - 01
# Patient NA18619: BCFTOOLS - 10, PLINK - 01
# Patient NA18629: BCFTOOLS - 10, PLINK - 01
# Patient NA18632: BCFTOOLS - 10, PLINK - 01
# Patient NA18633: BCFTOOLS - 10, PLINK - 01
# Patient NA18637: BCFTOOLS - 10, PLINK - 01
# Patient NA18639: BCFTOOLS - 10, PLINK - 01
# Patient NA18640: BCFTOOLS - 10, PLINK - 01
# Patient NA18642: BCFTOOLS - 10, PLINK - 01
# Patient NA18757: BCFTOOLS - 10, PLINK - 01
# Patient NA18870: BCFTOOLS - 10, PLINK - 01
# Patient NA18945: BCFTOOLS - 10, PLINK - 01
# Patient NA18949: BCFTOOLS - 10, PLINK - 01
# Patient NA18950: BCFTOOLS - 10, PLINK - 01
# Patient NA18951: BCFTOOLS - 10, PLINK - 01
# Patient NA18961: BCFTOOLS - 10, PLINK - 01
# Patient NA18964: BCFTOOLS - 10, PLINK - 01
# Patient NA18966: BCFTOOLS - 10, PLINK - 01
# Patient NA18971: BCFTOOLS - 10, PLINK - 01
# Patient NA18972: BCFTOOLS - 10, PLINK - 01
# Patient NA18973: BCFTOOLS - 10, PLINK - 01
# Patient NA18974: BCFTOOLS - 10, PLINK - 01
# Patient NA18979: BCFTOOLS - 10, PLINK - 01
# Patient NA18984: BCFTOOLS - 10, PLINK - 01
# Patient NA19000: BCFTOOLS - 10, PLINK - 01
# Patient NA19003: BCFTOOLS - 10, PLINK - 01
# Patient NA19062: BCFTOOLS - 10, PLINK - 01
# Patient NA19063: BCFTOOLS - 10, PLINK - 01
# Patient NA19066: BCFTOOLS - 10, PLINK - 01
# Patient NA19068: BCFTOOLS - 10, PLINK - 01
# Patient NA19072: BCFTOOLS - 10, PLINK - 01
# Patient NA19080: BCFTOOLS - 10, PLINK - 01
# Patient NA19090: BCFTOOLS - 10, PLINK - 01
# Patient NA19092: BCFTOOLS - 10, PLINK - 01
# Patient NA19095: BCFTOOLS - 10, PLINK - 01
# Patient NA19098: BCFTOOLS - 10, PLINK - 01
# Patient NA19102: BCFTOOLS - 10, PLINK - 01
# Patient NA19113: BCFTOOLS - 10, PLINK - 01
# Patient NA19121: BCFTOOLS - 10, PLINK - 01
# Patient NA19175: BCFTOOLS - 10, PLINK - 01
# Patient NA19190: BCFTOOLS - 10, PLINK - 01
# Patient NA19200: BCFTOOLS - 10, PLINK - 01
# Patient NA19206: BCFTOOLS - 10, PLINK - 01
# Patient NA19257: BCFTOOLS - 10, PLINK - 01
# Patient NA19307: BCFTOOLS - 10, PLINK - 01
# Patient NA19312: BCFTOOLS - 10, PLINK - 01
# Patient NA19372: BCFTOOLS - 10, PLINK - 01
# Patient NA19375: BCFTOOLS - 10, PLINK - 01
# Patient NA19376: BCFTOOLS - 10, PLINK - 01
# Patient NA19378: BCFTOOLS - 10, PLINK - 01
# Patient NA19397: BCFTOOLS - 10, PLINK - 01
# Patient NA19399: BCFTOOLS - 10, PLINK - 01
# Patient NA19428: BCFTOOLS - 10, PLINK - 01
# Patient NA19455: BCFTOOLS - 10, PLINK - 01
# Patient NA19720: BCFTOOLS - 10, PLINK - 01
# Patient NA19725: BCFTOOLS - 10, PLINK - 01
# Patient NA19740: BCFTOOLS - 10, PLINK - 01
# Patient NA19920: BCFTOOLS - 10, PLINK - 01
# Patient NA20127: BCFTOOLS - 10, PLINK - 01
# Patient NA20278: BCFTOOLS - 10, PLINK - 01
# Patient NA20281: BCFTOOLS - 10, PLINK - 01
# Patient NA20298: BCFTOOLS - 10, PLINK - 01
# Patient NA20314: BCFTOOLS - 10, PLINK - 01
# Patient NA20321: BCFTOOLS - 10, PLINK - 01
# Patient NA20340: BCFTOOLS - 10, PLINK - 01
# Patient NA20362: BCFTOOLS - 10, PLINK - 01
# Patient NA20512: BCFTOOLS - 10, PLINK - 01
# Patient NA20535: BCFTOOLS - 10, PLINK - 01
# Patient NA20539: BCFTOOLS - 10, PLINK - 01
# Patient NA20586: BCFTOOLS - 10, PLINK - 01
# Patient NA20799: BCFTOOLS - 10, PLINK - 01
# Patient NA20806: BCFTOOLS - 10, PLINK - 01
# Patient NA20811: BCFTOOLS - 10, PLINK - 01
# Patient NA20812: BCFTOOLS - 10, PLINK - 01
# Patient NA20875: BCFTOOLS - 10, PLINK - 01
# Patient NA20892: BCFTOOLS - 10, PLINK - 01
# Patient NA20899: BCFTOOLS - 10, PLINK - 01
# Patient NA21088: BCFTOOLS - 10, PLINK - 01
# Patient NA21089: BCFTOOLS - 10, PLINK - 01
# Patient NA21090: BCFTOOLS - 10, PLINK - 01
# Patient NA21091: BCFTOOLS - 10, PLINK - 01
# Patient NA21105: BCFTOOLS - 10, PLINK - 01
# Patient NA21118: BCFTOOLS - 10, PLINK - 01
# Patient NA21124: BCFTOOLS - 10, PLINK - 01
# Patient NA21127: BCFTOOLS - 10, PLINK - 01
# Patient NA21137: BCFTOOLS - 10, PLINK - 01
# Total number of patients with different genotypes: 299

# %%
# Check if the genotypes are equal between bcftools and grep

genotypes_equal = all(g1 == g2 for g1, g2 in zip(genotypes_bcftools, genotypes_grep))

if genotypes_equal:
    
    print(f"The genotypes for SNP {snp_id} are equal in both dataframes.")
else:
    print(f"The genotypes for SNP {snp_id} are not equal in both dataframes.")
    # Get the particular patients that are not equal
    counter = 0
    for patient_id, g1, g2 in zip(df_bcftools.columns, genotypes_bcftools, genotypes_grep):
        if g1 != g2:
            print(f"Patient {patient_id}: BCFTOOLS - {g1}, GREP - {g2}")
            counter += 1
    print(f"Total number of patients with different genotypes: {counter}")
# Out:
# The genotypes for SNP chr22_40904707 are equal in both dataframes.

# %%
import re
# Regular expression to extract chromosome number and position
pattern = r"chr(\d+)_([0-9]+)"

# Function to apply the pattern and format the string
def extract_format(s):
    match = re.match(pattern, s)
    if match:
        chromosome = match.group(1)
        position = match.group(2)
        return f"{chromosome}_{position}"
    else:
        return None

# Apply the function to the DataFrame index and create a list
formatted_list = [extract_format(index) for index in df.index]

print(formatted_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      13         return None
#      15 # Apply the function to the DataFrame index and create a list
# ---> 16 formatted_list = [extract_format(index) for index in df.index]
#      18 print(formatted_list)
#
# NameError: name 'df' is not defined

# %%
len(formatted_list)
# Out:
# 406

# %%
# Load the specific column from the Excel file
PRS_313_mutations = pd.read_excel("../PRS313.xlsx", usecols=["SNPa"])

# Function to remove everything after the second underscore
def remove_after_second_underscore(s):
    parts = s.split('_')
    if len(parts) > 2:
        return '_'.join(parts[:2])
    else:
        return s

# Apply the function to each string in the column
PRS_313_mutations['SNPa'] = PRS_313_mutations['SNPa'].apply(remove_after_second_underscore)

# %%
PRS_313_mutations.SNPa
# Out:
# 0      1_100880328
# 1       1_10566215
# 2      1_110198129
# 3      1_114445880
# 4      1_118141492
#           ...
# 308    22_39343916
# 309    22_40904707
# 310    22_43433100
# 311    22_45319953
# 312    22_46283297
# Name: SNPa, Length: 313, dtype: object

# %%
def difference_list(list_a, list_b):
    """
    Returns elements that are in list_a but not in list_b.
    
    Parameters:
    - list_a: First list.
    - list_b: Second list to compare against.
    
    Returns:
    A new list with elements that are in list_a but not in list_b.
    """
    return [item for item in list_a if item not in list_b]

# %%
missing_SNPs = difference_list(PRS_313_mutations.SNPa,formatted_list)

# %%
missing_SNPs
# Out:
# []

# %%
with open('../positions/missing_positions_2.txt', 'w') as file:
    for item in missing_SNPs:
        chromosome, position = item.split('_')
        file.write(f"{chromosome} {position}\n")

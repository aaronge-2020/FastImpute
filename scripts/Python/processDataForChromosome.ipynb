# %% [markdown]
# # Process Chromosome

# %%
import pandas as pd
import glob
import os

def read_vcf_header(file_path):
    """Reads the VCF file header (column names) and returns it."""
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('#CHROM'):
                return line.strip().split('\t')
    return []

def extract_snp_data(file_path, header):
    """Extracts SNP data from a VCF file."""
    snp_data = []
    with open(file_path, 'r') as file:
        for line in file:
            if not line.startswith('#'):
                fields = line.strip().split('\t')
                chrom, pos, ref, alt = fields[0], fields[1], fields[3], fields[4]
                snp_id = f"chr{chrom}_{pos}_{ref}_{alt}"
                genotype_data = fields[9:]  # Genotype data starts from the 10th column
                snp_data.append((snp_id, genotype_data))
    return snp_data

def process_vcf_files(directory):
    """Processes all VCF files in the specified directory."""
    vcf_files = glob.glob(os.path.join(directory, '*.vcf'))
    all_snp_data = []
    patient_ids = None
    
    for file_path in vcf_files:
        if patient_ids is None:
            patient_ids = read_vcf_header(file_path)[9:]  # Assuming the first 9 columns are standard VCF columns
        snp_data = extract_snp_data(file_path, patient_ids)

        if (len(snp_data) == 0):
            # print("No matches found at ", file_path)
            continue
        else:
            for SNP in snp_data:
                position_in_vcf = SNP[0].split("_")[1]
                file_path_position = file_path.split("_pos")[1][:-4]
                if (position_in_vcf == file_path_position):
                    all_snp_data.extend(snp_data)
                    # print("Adding")
                else:
                    # Ignoring copy number variations
                    # print("Ignoring")
                    continue

    # Convert the collected SNP data to a DataFrame
    data_dict = {snp_id: genotypes for snp_id, genotypes in all_snp_data}
    df = pd.DataFrame(data_dict, index=patient_ids)
    print(df.shape)
    return df

# %% [markdown]
# # Find intersection b/w 23AndMe and PRS313

# %%
import pandas as pd
import numpy as np
import sys

ttAndMeFullPanel = "../../Data/23andMe_metadata_files/23andMeGenePanel.csv"
# Read the text file into a DataFrame
ttAndMe = pd.read_csv(ttAndMeFullPanel)
# Read the text file into a DataFrame

# Read the PRS313.xlsx file into a DataFrame
PRS313_df = pd.read_csv('./concatenated_snps_processed.csv', index_col=0)

# Create a list of the column names in PRS313_df
PRS313_columns = PRS313_df.columns

# Create a list of the positions in PRS313_df
PRS313_positions = [col.split('_')[1] for col in PRS313_columns]

# Create a list of the chromosomes in PRS313_df. Parse only the integer values in the string 'chr2' to get the chromosome number
PRS313_chromosomes = [int(col.split('chr')[1].split('_')[0]) for col in PRS313_columns]

# Create a new row in PRS313_df to store the boolean values
PRS313_df.loc['in_23andMe'] = False

# Iterate over the rows in ttAndMe
for index, row in ttAndMe.iterrows():
    # Check if the current position and chromosome match any position and chromosome in PRS313
    if str(row['position']) in PRS313_positions and int(row['chromosome']) in PRS313_chromosomes:
        # If there's a match, find the corresponding column in PRS313_df and set the 'in_23andMe' value to True
        matching_column = [col for col in PRS313_columns if str(row['position']) in col and str(row['chromosome']) in col]
        if len(matching_column) > 0:
            PRS313_df.loc['in_23andMe', matching_column[0]] = True

# Print the updated PRS313_df DataFrame
print("Updated PRS313_df:")
print(PRS313_df)
# Out:
# Updated PRS313_df:
#            chr2_192381934_C_T chr8_129199566_G_A chr8_29509616_A_C  \
# HG00096                   1|1                0|1               1|1
# HG00097                   1|1                1|0               1|1
# HG00099                   1|1                0|0               0|0
# HG00100                   0|1                0|0               0|1
# HG00101                   1|1                0|0               1|1
# ...                       ...                ...               ...
# NA21141                   1|1                0|0               0|0
# NA21142                   1|0                1|0               0|1
# NA21143                   1|1                0|0               1|1
# NA21144                   1|1                0|0               0|1
# in_23andMe               True              False              True
#
#            chr2_121089731_T_C chr15_75750383_T_C chr18_24337424_C_G  \
# HG00096                   1|0                1|0                1|1
# HG00097                   0|0                0|0                0|1
# HG00099                   0|1                0|0                1|1
# HG00100                   0|0                0|0                0|1
# HG00101                   1|0                1|1                1|1
# ...                       ...                ...                ...
# NA21141                   0|0                0|1                1|1
# NA21142                   0|0                1|0                0|1
# NA21143                   0|0                1|1                0|1
# NA21144                   0|0                0|1                1|0
# in_23andMe               True              False               True
#
#            chr5_131640536_A_G chr16_4008542_CAAAAA_C chr16_10706580_G_A  \
# HG00096                   0|1                    1|1                0|0
# HG00097                   1|1                    1|1                0|0
# HG00099                   0|1                    1|1                0|0
# HG00100                   1|0                    1|1                0|0
# HG00101                   1|1                    1|1                0|0
# ...                       ...                    ...                ...
# NA21141                   1|1                    1|1                0|0
# NA21142                   0|1                    1|1                1|0
# NA21143                   0|1                    1|1                0|0
# NA21144                   0|0                    0|1                0|1
# in_23andMe              False                  False              False
#
#            chr9_110885479_C_T  ... chr12_120832146_C_T  \
# HG00096                   1|1  ...                 0|0
# HG00097                   1|0  ...                 1|0
# HG00099                   1|0  ...                 0|0
# HG00100                   1|1  ...                 0|1
# HG00101                   0|1  ...                 0|1
# ...                       ...  ...                 ...
# NA21141                   1|1  ...                 0|0
# NA21142                   1|1  ...                 1|0
# NA21143                   1|1  ...                 0|0
# NA21144                   1|1  ...                 1|0
# in_23andMe              False  ...                True
#
#            chr3_63887449_T_TTG,TTGTG chr4_126752992_A_AAT,AATAT  \
# HG00096                          0|0                        0|1
# HG00097                          0|1                        1|1
# HG00099                          0|0                        0|1
# HG00100                          1|0                        1|0
# HG00101                          0|1                        1|0
# ...                              ...                        ...
# NA21141                          0|0                        1|1
# NA21142                          0|1                        0|0
# NA21143                          0|0                        1|0
# NA21144                          0|0                        0|1
# in_23andMe                     False                      False
#
#            chr4_187503758_A_G,T chr4_84370124_TAA_TA,T chr5_176134882_T_A,C  \
# HG00096                     0|1                    0|1                  0|1
# HG00097                     0|1                    1|0                  1|0
# HG00099                     1|1                    0|0                  0|0
# HG00100                     1|0                    1|1                  1|1
# HG00101                     1|0                    1|0                  1|0
# ...                         ...                    ...                  ...
# NA21141                     0|0                    1|0                  1|1
# NA21142                     0|1                    0|1                  1|1
# NA21143                     0|1                    1|1                  0|0
# NA21144                     0|0                    1|0                  1|1
# in_23andMe                False                  False                False
#
#            chr5_52679539_C_CA,CAA chr7_91459189_A_AT,ATT chr10_22861490_A_C,T  \
# HG00096                       0|0                    1|0                  1|1
# HG00097                       0|0                    1|0                  1|1
# HG00099                       0|0                    1|1                  1|1
# HG00100                       0|0                    0|1                  0|1
# HG00101                       0|0                    0|0                  1|1
# ...                           ...                    ...                  ...
# NA21141                       0|0                    1|1                  1|1
# NA21142                       0|0                    0|1                  1|1
# NA21143                       1|0                    1|0                  0|1
# NA21144                       0|0                    1|0                  1|1
# in_23andMe                  False                  False                False
#
#            chr22_38583315_AAAAG_AAAAGAAAG,AAAAGAAAGAAAG,A
# HG00096                                               0|0
# HG00097                                               0|0
# HG00099                                               1|1
# HG00100                                               0|0
# HG00101                                               0|0
# ...                                                   ...
# NA21141                                               0|1
# NA21142                                               0|1
# NA21143                                               1|0
# NA21144                                               1|0
# in_23andMe                                          False
#
# [2505 rows x 313 columns]

# %%
sum(PRS313_df.loc['in_23andMe'])
# Out:
# 77

# %%
ttandMePositions = "../../Data/23andMe_metadata_files/23andMeGenePanel.csv"

output_dir   = "../../Data/Raw_training_data_23andMe_union/"

os.makedirs(output_dir, exist_ok=True)
# Read the text file into a DataFrame
ttAndMe = pd.read_csv(ttandMePositions, comment='#', header = 0)
for i in range (1, 23):
    chromosome_number = i
        
    # Replace 'your_directory_path' with the path to your directory containing the VCF files
    directory_path = f'../../Data/23AndMePositionsUnion/chr{chromosome_number}/'
    df_23AndMe = process_vcf_files(directory_path)


    # Filter the PRS313 data to only include SNPs on chromosome 1 by filtering column names that begin with chr1
    chromosome_N_snps = PRS313_df.loc[:, [col for col in PRS313_df.columns if col.startswith(f'chr{chromosome_number}_')]]

    # If the df_23AndMe DataFrame column has a matching column in the PRS313 DataFrame, add to its column name the string '_PRS313'
    cols_renamed = []
    for column in df_23AndMe.columns:
        if column in chromosome_N_snps.columns:
            df_23AndMe.rename(columns={column: f'{column}_PRS313_Known'}, inplace=True)
            cols_renamed.append(column)
            print(f"Column {column} renamed to {column}_PRS313_Known")
            
    print(len(cols_renamed))

    # Add the columns from the PRS313 DataFrame that were not present in the 23andMe DataFrame. Use the 'in_23AndMe' row to add only the rows that weren't already there. Ensure that there is a '_PRS313_Unknown' suffix in the column name

    added_columns = []
    for column in chromosome_N_snps.columns:
        if not chromosome_N_snps.loc['in_23andMe', column]:
            df_23AndMe[column + '_PRS313_Unknown'] = chromosome_N_snps.loc[:, column]
            added_columns.append(column)
            print(f"Column {column} added to df_23AndMe with suffix '_PRS313_Unknown'")
    print(len(added_columns))

    df_23AndMe.to_parquet(f'{output_dir}/23AndMe_PRS313_merged_chr{chromosome_number}.parquet')
# Out:
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos215955412.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos25880491.vcf
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos237796920.vcf
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos197065212.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos112043141.vcf
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos17359631.vcf
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos209797346.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos152187195.vcf
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos248458383.vcf
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos17371368.vcf
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos36937075.vcf
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos145360621.vcf
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos43396377.vcf
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos236572512.vcf
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos146055400.vcf
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos55529206.vcf
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos33832738.vcf
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos55521896.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos97544549.vcf
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos236631524.vcf
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos12067224.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos97544561.vcf
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos55525212.vcf
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos215901484.vcf
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos235613570.vcf
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos17359553.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos156105059.vcf
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos160039811.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos237991713.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos201328767.vcf
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos156084786.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos32792645.vcf
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos241665837.vcf
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos227173033.vcf
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos201063084.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos145320601.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos212900503.vcf
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos43301433.vcf
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos248637474.vcf
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos45407182.vcf
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos25883760.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos160012129.vcf
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos7870653.vcf
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos241675358.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos55529159.vcf
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos197062385.vcf
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos55518390.vcf
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos236645703.vcf
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos216465541.vcf
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos43395284.vcf
# Adding
# Ignoring
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# No matches found at  ../../Data/23AndMePositionsUnion/chr1/chr1_pos43304589.vcf
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Ignoring
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Ignoring
# Adding
# Adding
# Adding
# Ignoring
# Adding
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[155], line 13
#      11 # Replace 'your_directory_path' with the path to your directory containing the VCF files
#      12 directory_path = f'../../Data/23AndMePositionsUnion/chr{chromosome_number}/'
# ---> 13 df_23AndMe = process_vcf_files(directory_path)
#      16 # Filter the PRS313 data to only include SNPs on chromosome 1 by filtering column names that begin with chr1
#      17 chromosome_N_snps = PRS313_df.loc[:, [col for col in PRS313_df.columns if col.startswith(f'chr{chromosome_number}_')]]
#
# Cell In[137], line 35, in process_vcf_files(directory)
#      33 if patient_ids is None:
#      34     patient_ids = read_vcf_header(file_path)[9:]  # Assuming the first 9 columns are standard VCF columns
# ---> 35 snp_data = extract_snp_data(file_path, patient_ids)
#      37 if (len(snp_data) == 0):
#      38     print("No matches found at ", file_path)
#
# Cell In[137], line 19, in extract_snp_data(file_path, header)
#      17 for line in file:
#      18     if not line.startswith('#'):
# ---> 19         fields = line.strip().split('\t')
#      20         chrom, pos, ref, alt = fields[0], fields[1], fields[3], fields[4]
#      21         snp_id = f"chr{chrom}_{pos}_{ref}_{alt}"
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

# Directory containing the parquet files
directory = "../Final_training_data/"

# Iterate over the files in the directory
for filename in os.listdir(directory):
    if filename.startswith("23AndMe_PRS313_merged_chr") and filename.endswith(".parquet"):
        file_path = os.path.join(directory, filename)
        
        # Extract the chromosome number from the filename
        chromosome = filename.split("_")[-1].split(".")[0]
        
        # Read the parquet file into a DataFrame
        df = pd.read_parquet(file_path)
        
        # Filter the columns starting with "chrN_"
        filtered_columns = [col for col in df.columns if col.startswith(f"{chromosome}_")]
        filtered_df = df[filtered_columns]
        
        # Replace the original parquet file with the filtered DataFrame
        filtered_df.to_parquet(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 23
#      20 filtered_df = df[filtered_columns]
#      22 # Replace the original parquet file with the filtered DataFrame
# ---> 23 filtered_df.to_parquet(file_path, index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:2973, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2885 """
#    2886 Write a DataFrame to the binary parquet format.
#    2887
#    (...)
#    2969 >>> content = f.read()
#    2970 """
#    2971 from pandas.io.parquet import to_parquet
# -> 2973 return to_parquet(
#    2974     self,
#    2975     path,
#    2976     engine,
#    2977     compression=compression,
#    2978     index=index,
#    2979     partition_cols=partition_cols,
#    2980     storage_options=storage_options,
#    2981     **kwargs,
#    2982 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parquet.py:483, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     479 impl = get_engine(engine)
#     481 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 483 impl.write(
#     484     df,
#     485     path_or_buf,
#     486     compression=compression,
#     487     index=index,
#     488     partition_cols=partition_cols,
#     489     storage_options=storage_options,
#     490     filesystem=filesystem,
#     491     **kwargs,
#     492 )
#     494 if path is None:
#     495     assert isinstance(path_or_buf, io.BytesIO)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parquet.py:189, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     186 if index is not None:
#     187     from_pandas_kwargs["preserve_index"] = index
# --> 189 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     191 if df.attrs:
#     192     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/table.pxi:3874, in pyarrow.lib.Table.from_pandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/pandas_compat.py:570, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     562 def dataframe_to_arrays(df, schema, preserve_index, nthreads=1, columns=None,
#     563                         safe=True):
#     564     (all_names,
#     565      column_names,
#     566      index_column_names,
#     567      index_descriptors,
#     568      index_columns,
#     569      columns_to_convert,
# --> 570      convert_fields) = _get_columns_to_convert(df, schema, preserve_index,
#     571                                                columns)
#     573     # NOTE(wesm): If nthreads=None, then we use a heuristic to decide whether
#     574     # using a thread pool is worth it. Currently the heuristic is whether the
#     575     # nrows > 100 * ncols and ncols > 1.
#     576     if nthreads is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/pandas_compat.py:370, in _get_columns_to_convert(df, schema, preserve_index, columns)
#     367 convert_fields = []
#     369 for name in columns:
# --> 370     col = df[name]
#     371     name = _column_name_to_strings(name)
#     373     if _pandas_api.is_sparse(col):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3872, in DataFrame.__getitem__(self, key)
#    3865 # GH#45316 Return view if key is not duplicated
#    3866 # Only use drop_duplicates with duplicates for performance
#    3867 if not is_mi and (
#    3868     self.columns.is_unique
#    3869     and key in self.columns
#    3870     or key in self.columns.drop_duplicates(keep=False)
#    3871 ):
# -> 3872     return self._get_item_cache(key)
#    3874 elif is_mi and self.columns.is_unique and key in self.columns:
#    3875     return self._getitem_multilevel(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4418, in DataFrame._get_item_cache(self, item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
#    4417     loc = self.columns.get_loc(item)
# -> 4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#    4422     # for a chain
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3806, in DataFrame._ixs(self, i, axis)
#    3802 # icol
#    3803 else:
#    3804     label = self.columns[i]
# -> 3806     col_mgr = self._mgr.iget(i)
#    3807     result = self._box_col_values(col_mgr, i)
#    3809     # this is a cached value, mark it so
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1000, in BlockManager.iget(self, i, track_ref)
#     998 # shortcut for select a single-dim from a 2-dim BM
#     999 bp = BlockPlacement(slice(0, len(values)))
# -> 1000 nb = type(block)(
#    1001     values, placement=bp, ndim=1, refs=block.refs if track_ref else None
#    1002 )
#    1003 return SingleBlockManager(nb, self.axes[1])
#
# KeyboardInterrupt:

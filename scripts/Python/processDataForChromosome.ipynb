# %%
import pandas as pd
import glob
import os

def read_vcf_header(file_path):
    """Reads the VCF file header (column names) and returns it."""
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('#CHROM'):
                return line.strip().split('\t')
    return []

def extract_snp_data(file_path, header):
    """Extracts SNP data from a VCF file."""
    snp_data = []
    with open(file_path, 'r') as file:
        for line in file:
            if not line.startswith('#'):
                fields = line.strip().split('\t')
                chrom, pos, ref, alt = fields[0], fields[1], fields[3], fields[4]
                snp_id = f"chr{chrom}_{pos}_{ref}_{alt}"
                genotype_data = fields[9:]  # Genotype data starts from the 10th column
                snp_data.append((snp_id, genotype_data))
    return snp_data

def process_vcf_files(directory):
    """Processes all VCF files in the specified directory."""
    vcf_files = glob.glob(os.path.join(directory, '*.vcf'))
    all_snp_data = []
    patient_ids = None
    
    for file_path in vcf_files:
        if patient_ids is None:
            patient_ids = read_vcf_header(file_path)[9:]  # Assuming the first 9 columns are standard VCF columns
        snp_data = extract_snp_data(file_path, patient_ids)
        all_snp_data.extend(snp_data)

    # Convert the collected SNP data to a DataFrame
    data_dict = {snp_id: genotypes for snp_id, genotypes in all_snp_data}
    df = pd.DataFrame(data_dict, index=patient_ids)
    
    return df

# %% [markdown]
# # Find intersection b/w 23AndMe and PRS313

# %%
import pandas as pd
import numpy as np
import sys

ExampleData = "../../genome_Chad_Wrye_v5_Full_20220921063742.txt"

# Read the text file into a DataFrame
ttAndMe = pd.read_csv(ExampleData, sep='\t', comment='#', header=None, names=['rsid', 'chromosome', 'position', 'genotype'])

# Read the PRS313.xlsx file into a DataFrame
PRS313_df = pd.read_excel('../../Data/PRS313.xlsx', index_col=0)

# Create a list of the column names in PRS313_df
PRS313_columns = PRS313_df.columns

# Create a list of the positions in PRS313_df
PRS313_positions = [col.split('_')[1] for col in PRS313_columns]

# Create a list of the chromosomes in PRS313_df. Parse only the integer values in the string 'chr2' to get the chromosome number
PRS313_chromosomes = [int(col.split('chr')[1].split('_')[0]) for col in PRS313_columns]

# Create a new row in PRS313_df to store the boolean values
PRS313_df.loc['in_23andMe'] = False

# Iterate over the rows in ttAndMe
for index, row in ttAndMe.iterrows():
    # Check if the current position and chromosome match any position and chromosome in PRS313
    if str(row['position']) in PRS313_positions and row['chromosome'] in PRS313_chromosomes:
        # If there's a match, find the corresponding column in PRS313_df and set the 'in_23andMe' value to True
        matching_column = [col for col in PRS313_columns if str(row['position']) in col and str(row['chromosome']) in col]
        if len(matching_column) > 0:
            PRS313_df.loc['in_23andMe', matching_column[0]] = True

# Print the updated PRS313_df DataFrame
print("Updated PRS313_df:")
print(PRS313_df)
# Out:
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_98829/1970839588.py:8: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   ttAndMe = pd.read_csv(ExampleData, sep='\t', comment='#', header=None, names=['rsid', 'chromosome', 'position', 'genotype'])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 17
#      14 PRS313_columns = PRS313_df.columns
#      16 # Create a list of the positions in PRS313_df
# ---> 17 PRS313_positions = [col.split('_')[1] for col in PRS313_columns]
#      19 # Create a list of the chromosomes in PRS313_df. Parse only the integer values in the string 'chr2' to get the chromosome number
#      20 PRS313_chromosomes = [int(col.split('chr')[1].split('_')[0]) for col in PRS313_columns]
#
# Cell In[4], line 17, in <listcomp>(.0)
#      14 PRS313_columns = PRS313_df.columns
#      16 # Create a list of the positions in PRS313_df
# ---> 17 PRS313_positions = [col.split('_')[1] for col in PRS313_columns]
#      19 # Create a list of the chromosomes in PRS313_df. Parse only the integer values in the string 'chr2' to get the chromosome number
#      20 PRS313_chromosomes = [int(col.split('chr')[1].split('_')[0]) for col in PRS313_columns]
#
# IndexError: list index out of range

# %%
for i in range (1, 23):
    chromosome_number = i
        
    # Replace 'your_directory_path' with the path to your directory containing the VCF files
    directory_path = f'../23AndMePositions/chr{chromosome_number}/'
    df_23AndMe = process_vcf_files(directory_path)


    # Filter the PRS313 data to only include SNPs on chromosome 1 by filtering column names that begin with chr1
    chromosome_N_snps = PRS313_df.loc[:, [col for col in PRS313_df.columns if col.startswith(f'chr{chromosome_number}_')]]

    # If the df_23AndMe DataFrame column has a matching column in the PRS313 DataFrame, add to its column name the string '_PRS313'
    cols_renamed = []
    for column in df_23AndMe.columns:
        if column in chromosome_N_snps.columns:
            df_23AndMe.rename(columns={column: f'{column}_PRS313_Known'}, inplace=True)
            cols_renamed.append(column)
            print(f"Column {column} renamed to {column}_PRS313_Known")
    print(len(cols_renamed))

    # Add the columns from the PRS313 DataFrame that were not present in the 23andMe DataFrame. Use the 'in_23AndMe' row to add only the rows that weren't already there. Ensure that there is a '_PRS313_Unknown' suffix in the column name

    added_columns = []
    for column in chromosome_N_snps.columns:
        if not chromosome_N_snps.loc['in_23andMe', column]:
            df_23AndMe[column + '_PRS313_Unknown'] = chromosome_N_snps.loc[:, column]
            added_columns.append(column)
            print(f"Column {column} added to df_23AndMe with suffix '_PRS313_Unknown'")

    print(len(added_columns))

    df_23AndMe.to_parquet(f'../Final_training_data/23AndMe_PRS313_merged_chr{chromosome_number}.parquet')
# Out:
# Column chr1_121280613_A_G renamed to chr1_121280613_A_G_PRS313_Known
# Column chr1_120257110_T_C renamed to chr1_120257110_T_C_PRS313_Known
# Column chr1_10566215_A_G renamed to chr1_10566215_A_G_PRS313_Known
# Column chr1_149906413_T_C renamed to chr1_149906413_T_C_PRS313_Known
# Column chr1_41380440_C_T renamed to chr1_41380440_C_T_PRS313_Known
# Column chr1_242034263_A_G renamed to chr1_242034263_A_G_PRS313_Known
# Column chr1_88156923_G_A renamed to chr1_88156923_G_A_PRS313_Known
# Column chr1_217220574_G_A renamed to chr1_217220574_G_A_PRS313_Known
# Column chr1_201437832_C_T renamed to chr1_201437832_C_T_PRS313_Known
# Column chr1_18807339_T_C renamed to chr1_18807339_T_C_PRS313_Known
# 10
# Column chr1_110198129_CAAA_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_202184600_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_168171052_CA_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_118141492_A_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_114445880_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_100880328_A_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_208076291_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_220671050_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_88428199_C_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_145604302_C_CT added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_217053815_T_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_203770448_T_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_7917076_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_121287994_A_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_172328767_T_TA added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_41389220_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_46670206_TC_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_204502514_T_TTCTGAAACAGGG added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr1_155556971_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column ch
A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr16_4106788_C_A added to df_23AndMe with suffix '_PRS313_Unknown'
# 11
# Column chr17_77781725_A_G renamed to chr17_77781725_A_G_PRS313_Known
# Column chr17_53209774_A_C renamed to chr17_53209774_A_C_PRS313_Known
# 2
# Column chr17_39251123_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_40744470_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_77781725_A_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_29168077_G_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_40127060_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_43212339_C_CT added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_53209774_A_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_40485239_G_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr17_44283858_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# 9
# Column chr18_24337424_C_G renamed to chr18_24337424_C_G_PRS313_Known
# Column chr18_11696613_C_T renamed to chr18_11696613_C_T_PRS313_Known
# 2
# Column chr18_24337424_C_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_42888797_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_24125857_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_29981526_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_20634253_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_42411803_G_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_11696613_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_24518050_AT_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr18_25407513_C_G added to df_23AndMe with suffix '_PRS313_Unknown'
# 9
# 0
# Column chr19_18569492_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr19_46166073_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr19_44283031_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr19_19517054_C_CGGGCG added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr19_17393925_C_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr19_13249921_G_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr19_55816678_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# 7
# Column chr20_5948227_G_A renamed to chr20_5948227_G_A_PRS313_Known
# 1
# Column chr20_52296849_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr20_11379842_T_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr20_41613706_C_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr20_5948227_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# 4
# Column chr21_16364756_T_G renamed to chr21_16364756_T_G_PRS313_Known
# Column chr21_16574455_C_A renamed to chr21_16574455_C_A_PRS313_Known
# 2
# Column chr21_16364756_T_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr21_16574455_C_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr21_16566350_A_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr21_47762932_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# 4
# Column chr22_39343916_T_A renamed to chr22_39343916_T_A_PRS313_Known
# Column chr22_29121087_A_G renamed to chr22_29121087_A_G_PRS313_Known
# Column chr22_40904707_CT_C renamed to chr22_40904707_CT_C_PRS313_Known
# 3
# Column chr22_43433100_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_45319953_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_46283297_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_39343916_T_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_40904707_CT_C added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_19766137_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_29203724_C_T added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_29135543_G_A added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_29121087_A_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_29551872_A_G added to df_23AndMe with suffix '_PRS313_Unknown'
# Column chr22_38583315_AAAAG_AAAAGAAAG,AAAAGAAAGAAAG,A added to df_23AndMe with suffix '_PRS313_Unknown'
# 11

# %%
import os
import pandas as pd

# Directory containing the parquet files
directory = "../Final_training_data/"

# Iterate over the files in the directory
for filename in os.listdir(directory):
    if filename.startswith("23AndMe_PRS313_merged_chr") and filename.endswith(".parquet"):
        file_path = os.path.join(directory, filename)
        
        # Extract the chromosome number from the filename
        chromosome = filename.split("_")[-1].split(".")[0]
        
        # Read the parquet file into a DataFrame
        df = pd.read_parquet(file_path)
        
        # Filter the columns starting with "chrN_"
        filtered_columns = [col for col in df.columns if col.startswith(f"{chromosome}_")]
        filtered_df = df[filtered_columns]
        
        # Replace the original parquet file with the filtered DataFrame
        filtered_df.to_parquet(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 23
#      20 filtered_df = df[filtered_columns]
#      22 # Replace the original parquet file with the filtered DataFrame
# ---> 23 filtered_df.to_parquet(file_path, index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:2973, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2885 """
#    2886 Write a DataFrame to the binary parquet format.
#    2887
#    (...)
#    2969 >>> content = f.read()
#    2970 """
#    2971 from pandas.io.parquet import to_parquet
# -> 2973 return to_parquet(
#    2974     self,
#    2975     path,
#    2976     engine,
#    2977     compression=compression,
#    2978     index=index,
#    2979     partition_cols=partition_cols,
#    2980     storage_options=storage_options,
#    2981     **kwargs,
#    2982 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parquet.py:483, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     479 impl = get_engine(engine)
#     481 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 483 impl.write(
#     484     df,
#     485     path_or_buf,
#     486     compression=compression,
#     487     index=index,
#     488     partition_cols=partition_cols,
#     489     storage_options=storage_options,
#     490     filesystem=filesystem,
#     491     **kwargs,
#     492 )
#     494 if path is None:
#     495     assert isinstance(path_or_buf, io.BytesIO)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parquet.py:189, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     186 if index is not None:
#     187     from_pandas_kwargs["preserve_index"] = index
# --> 189 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     191 if df.attrs:
#     192     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/table.pxi:3874, in pyarrow.lib.Table.from_pandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/pandas_compat.py:570, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     562 def dataframe_to_arrays(df, schema, preserve_index, nthreads=1, columns=None,
#     563                         safe=True):
#     564     (all_names,
#     565      column_names,
#     566      index_column_names,
#     567      index_descriptors,
#     568      index_columns,
#     569      columns_to_convert,
# --> 570      convert_fields) = _get_columns_to_convert(df, schema, preserve_index,
#     571                                                columns)
#     573     # NOTE(wesm): If nthreads=None, then we use a heuristic to decide whether
#     574     # using a thread pool is worth it. Currently the heuristic is whether the
#     575     # nrows > 100 * ncols and ncols > 1.
#     576     if nthreads is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/pandas_compat.py:370, in _get_columns_to_convert(df, schema, preserve_index, columns)
#     367 convert_fields = []
#     369 for name in columns:
# --> 370     col = df[name]
#     371     name = _column_name_to_strings(name)
#     373     if _pandas_api.is_sparse(col):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3872, in DataFrame.__getitem__(self, key)
#    3865 # GH#45316 Return view if key is not duplicated
#    3866 # Only use drop_duplicates with duplicates for performance
#    3867 if not is_mi and (
#    3868     self.columns.is_unique
#    3869     and key in self.columns
#    3870     or key in self.columns.drop_duplicates(keep=False)
#    3871 ):
# -> 3872     return self._get_item_cache(key)
#    3874 elif is_mi and self.columns.is_unique and key in self.columns:
#    3875     return self._getitem_multilevel(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4418, in DataFrame._get_item_cache(self, item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
#    4417     loc = self.columns.get_loc(item)
# -> 4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#    4422     # for a chain
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3806, in DataFrame._ixs(self, i, axis)
#    3802 # icol
#    3803 else:
#    3804     label = self.columns[i]
# -> 3806     col_mgr = self._mgr.iget(i)
#    3807     result = self._box_col_values(col_mgr, i)
#    3809     # this is a cached value, mark it so
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1000, in BlockManager.iget(self, i, track_ref)
#     998 # shortcut for select a single-dim from a 2-dim BM
#     999 bp = BlockPlacement(slice(0, len(values)))
# -> 1000 nb = type(block)(
#    1001     values, placement=bp, ndim=1, refs=block.refs if track_ref else None
#    1002 )
#    1003 return SingleBlockManager(nb, self.axes[1])
#
# KeyboardInterrupt:

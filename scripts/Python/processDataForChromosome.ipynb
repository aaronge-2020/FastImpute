# %% [markdown]
# # Process Chromosome

# %%
import pandas as pd
import glob
import os
import re

def extract_snp_data(file_path):
    """Extracts SNP data from a VCF file."""
    error_log = []
    
    # Extract the original sample names from the VCF header
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('#CHROM'):
                headers = line.strip().split('\t')
                break
    
    try:
        vcf_df = pd.read_csv(file_path, sep='\t', comment='#', names=headers)
    except pd.errors.EmptyDataError:
        error_log.append([f'Error: No data found.', file_path])
        return None, error_log
    
    # Use os.path.splitext() to extract the file extension
    filename, _ = os.path.splitext(file_path)
    filename_parts = filename.split('chr')[-1].split("_pos")
    
    # Split by underscores
    # Get the chromosome number (removing 'chr' prefix)
    # chromosome_number = filename_parts[0]
    # Get the position
    position = filename_parts[1]
    
    # Use df.query() to find matching rows
    matching_rows = vcf_df.query(f"POS == {position}").index
    
    if len(matching_rows) > 1:
        error_log.append([f"Error: More than one match found", file_path])
        # print("Error: More than one match found")
        matching_index = matching_rows
        return vcf_df.iloc[matching_index], error_log
    elif len(matching_rows) == 0:
        # print("Error: No matches found")
        error_log.append([f"Error: No matches found", file_path])
        return None, error_log
    else:
        # print("Successfully processed: ", file_path)
        matching_index = matching_rows[0]
        return vcf_df.iloc[matching_index], error_log

def process_vcf_files(directory, error_logs_dir):
    """Processes all VCF files in the specified directory."""
    vcf_files = glob.glob(os.path.join(directory, '*.vcf'))
    all_snp_data = []
    all_error_logs = []
    
    for file_path in vcf_files[0:10]:
        snp_data, error_log = extract_snp_data(file_path)
        if snp_data is not None:
            all_snp_data.append(snp_data)
        all_error_logs.extend(error_log)
    
    # Save error logs to a TSV file

    error_log_df = pd.DataFrame(all_error_logs, columns=['Error', "File"])
    error_log_df['Error'] = error_log_df['Error'].astype(str)
    error_log_df['File'] = error_log_df['File'].astype(str)
    error_log_df.to_csv(os.path.join(error_logs_dir, 'error_log.csv'), index=False)
    
    print("Finished processing directory: ", directory)
    
    # Concatenate all SNP data into a single DataFrame
    if all_snp_data:
        df = pd.DataFrame(all_snp_data)
        return df
    else:
        return None

# %% [markdown]
# # Find intersection b/w 23AndMe and PRS313

# %%
import pandas as pd
import numpy as np
import sys

ttAndMeFullPanel = "../../Data/23andMe_metadata_files/23andMeGenePanel.csv"
# Read the text file into a DataFrame
ttAndMe = pd.read_csv(ttAndMeFullPanel)

# Read the PRS313.xlsx file into a DataFrame
PRS313_df = pd.read_excel('../../Data/PRS313_with_23andMe_chad.xlsx')

# Create a new row in PRS313_df to store the boolean values
PRS313_df.loc['in_23andMe'] = False

# Iterate over the rows in PRS313_df
for index, row in PRS313_df.iterrows():
    if index == 'in_23andMe':
        continue  # Skip the 'in_23andMe' row
    
    # Extract the position and chromosome from the current row
    position = row['Position']
    chromosome = row['Chromosome']
    
    # Check if the current position and chromosome exist in the 23andMe dataframe
    if ((ttAndMe['position'] == position) & (ttAndMe['chromosome'] == chromosome)).any():
        PRS313_df.loc[index, 'in_23andMe'] = True


# Print the updated PRS313_df DataFrame

print("Total number of SNPs in 23andMe data:", PRS313_df['in_23andMe'].sum())
PRS313_df.to_excel('../../Data/PRS313_with_23andMe_Full.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 25
#      22     chromosome = row['Chromosome']
#      24     # Check if the current position and chromosome exist in the 23andMe dataframe
# ---> 25     if ((ttAndMe['position'] == position) & (ttAndMe['chromosome'] == chromosome)).any():
#      26         PRS313_df.loc[index, 'in_23andMe'] = True
#      29 # Print the updated PRS313_df DataFrame
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
PRS313_df = pd.read_excel('../../Data/PRS313_with_23andMe_Full.xlsx')

# %%
ttandMePositions = "../../Data/23andMe_metadata_files/23andMeGenePanel.csv"

output_dir   = "../../Data/Raw_training_data_23andMe_union/"

os.makedirs(output_dir, exist_ok=True)
# Read the text file into a DataFrame
ttAndMe = pd.read_csv(ttandMePositions, comment='#', header = 0)

for i in range(1, 23):
    chromosome_number = i
    
    # Replace 'your_directory_path' with the path to your directory containing the VCF files
    directory_path = f'../../Data/23AndMePositionsUnion/chr{chromosome_number}/'
    
    df_23AndMe = process_vcf_files(directory_path, "../../Data/23AndMePositionsUnion/")
    
    # Filter the PRS313 data to only include SNPs on chromosome 1 by filtering column names that begin with chr1
    chromosome_N_snps = PRS313_df.loc[:, [col for col in PRS313_df.columns if col.startswith(f'chr{chromosome_number}_')]]
    
    # If the df_23AndMe DataFrame column has a matching column in the PRS313 DataFrame, add to its column name the string '_PRS313'
    cols_renamed = []
    for column in df_23AndMe.columns:
        if column in chromosome_N_snps.columns:
            df_23AndMe.rename(columns={column: f'{column}_PRS313_Known'}, inplace=True)
            cols_renamed.append(column)
            print(f"Column {column} renamed to {column}_PRS313_Known")
    print(len(cols_renamed))
    
    # Add the columns from the PRS313 DataFrame that were not present in the 23andMe DataFrame. Use the 'in_23AndMe' row to add only the rows that weren't already there. Ensure that there is a '_PRS313_Unknown' suffix in the column name
    added_columns = []
    for column in chromosome_N_snps.columns:
        if not chromosome_N_snps.loc['in_23andMe', column]:
            df_23AndMe[column + '_PRS313_Unknown'] = chromosome_N_snps.loc[:, column]
            added_columns.append(column)
            print(f"Column {column} added to df_23AndMe with suffix '_PRS313_Unknown'")
    print(len(added_columns))
    
    df_23AndMe.to_parquet(f'{output_dir}/23AndMe_PRS313_merged_chr{chromosome_number}.parquet')
# Out:
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos4060196.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos207509287.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos193469300.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos90477520.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos162832406.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos21999437.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos233057152.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos98186118.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos103765339.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr1/chr1_pos91504195.vcf
# Finished processing directory:  ../../Data/23AndMePositionsUnion/chr1/
# 0
# 0
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos184653608.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos210618278.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos231452647.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos46558541.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos118016307.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos177165375.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos77919714.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos160193992.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos45381259.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr2/chr2_pos169783209.vcf
# Finished processing directory:  ../../Data/23AndMePositionsUnion/chr2/
# 0
# 0
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos1231334.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos167604119.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos86602789.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos50720909.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos41475001.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos191875957.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos177268890.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos17180725.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos81956982.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr3/chr3_pos136558135.vcf
# Finished processing directory:  ../../Data/23AndMePositionsUnion/chr3/
# 0
# 0
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos120692781.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos38980141.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos54750921.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos131745954.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos148302638.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos177469850.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos12209039.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos157913478.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos153874666.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr4/chr4_pos89739808.vcf
# Finished processing directory:  ../../Data/23AndMePositionsUnion/chr4/
# 0
# 0
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos152669830.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos2763503.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos38919117.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos139322405.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos148305690.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos68200642.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos117225061.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos156635312.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos68389714.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr5/chr5_pos159221715.vcf
# Finished processing directory:  ../../Data/23AndMePositionsUnion/chr5/
# 0
# 0
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos9423728.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos38759379.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos37082809.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos33117659.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos32804414.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos140194296.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos80332105.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos163556969.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos11530965.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr6/chr6_pos91490914.vcf
# Finished processing directory:  ../../Data/23AndMePositionsUnion/chr6/
# 0
# 0
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr7/chr7_pos33352910.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr7/chr7_pos15363996.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr7/chr7_pos22154454.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr7/chr7_pos54814083.vcf
# Successfully processed:  ../../Data/23AndMePositionsUnion/chr7/chr7_pos36775986.vcf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 15
#      12 # Replace 'your_directory_path' with the path to your directory containing the VCF files
#      13 directory_path = f'../../Data/23AndMePositionsUnion/chr{chromosome_number}/'
# ---> 15 df_23AndMe = process_vcf_files(directory_path, "../../Data/23AndMePositionsUnion/")
#      17 # Filter the PRS313 data to only include SNPs on chromosome 1 by filtering column names that begin with chr1
#      18 chromosome_N_snps = PRS313_df.loc[:, [col for col in PRS313_df.columns if col.startswith(f'chr{chromosome_number}_')]]
#
# Cell In[85], line 58, in process_vcf_files(directory, error_logs_dir)
#      55 all_error_logs = []
#      57 for file_path in vcf_files[0:10]:
# ---> 58     snp_data, error_log = extract_snp_data(file_path)
#      59     if snp_data is not None:
#      60         all_snp_data.append(snp_data)
#
# Cell In[85], line 34, in extract_snp_data(file_path)
#      31 position = filename_parts[1]
#      33 # Use df.query() to find matching rows
# ---> 34 matching_rows = vcf_df.query(f"POS == {position}").index
#      36 if len(matching_rows) > 1:
#      37     error_log.append([f"Error: More than one match found", file_path])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4602, in DataFrame.query(self, expr, inplace, **kwargs)
#    4600 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4601 kwargs["target"] = None
# -> 4602 res = self.eval(expr, **kwargs)
#    4604 try:
#    4605     result = self.loc[res]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4722, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4720 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4721 index_resolvers = self._get_index_resolvers()
# -> 4722 column_resolvers = self._get_cleaned_column_resolvers()
#    4723 resolvers = column_resolvers, index_resolvers
#    4724 if "target" not in kwargs:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:634, in NDFrame._get_cleaned_column_resolvers(self)
#     631 if isinstance(self, ABCSeries):
#     632     return {clean_column_name(self.name): self}
# --> 634 return {
#     635     clean_column_name(k): v for k, v in self.items() if not isinstance(k, int)
#     636 }
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:634, in <dictcomp>(.0)
#     631 if isinstance(self, ABCSeries):
#     632     return {clean_column_name(self.name): self}
# --> 634 return {
#     635     clean_column_name(k): v for k, v in self.items() if not isinstance(k, int)
#     636 }
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:1399, in DataFrame.items(self)
#    1397 if self.columns.is_unique and hasattr(self, "_item_cache"):
#    1398     for k in self.columns:
# -> 1399         yield k, self._get_item_cache(k)
#    1400 else:
#    1401     for i, k in enumerate(self.columns):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4418, in DataFrame._get_item_cache(self, item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
#    4417     loc = self.columns.get_loc(item)
# -> 4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#    4422     # for a chain
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3806, in DataFrame._ixs(self, i, axis)
#    3802 # icol
#    3803 else:
#    3804     label = self.columns[i]
# -> 3806     col_mgr = self._mgr.iget(i)
#    3807     result = self._box_col_values(col_mgr, i)
#    3809     # this is a cached value, mark it so
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1000, in BlockManager.iget(self, i, track_ref)
#     998 # shortcut for select a single-dim from a 2-dim BM
#     999 bp = BlockPlacement(slice(0, len(values)))
# -> 1000 nb = type(block)(
#    1001     values, placement=bp, ndim=1, refs=block.refs if track_ref else None
#    1002 )
#    1003 return SingleBlockManager(nb, self.axes[1])
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

# Directory containing the parquet files
directory = "../Final_training_data/"

# Iterate over the files in the directory
for filename in os.listdir(directory):
    if filename.startswith("23AndMe_PRS313_merged_chr") and filename.endswith(".parquet"):
        file_path = os.path.join(directory, filename)
        
        # Extract the chromosome number from the filename
        chromosome = filename.split("_")[-1].split(".")[0]
        
        # Read the parquet file into a DataFrame
        df = pd.read_parquet(file_path)
        
        # Filter the columns starting with "chrN_"
        filtered_columns = [col for col in df.columns if col.startswith(f"{chromosome}_")]
        filtered_df = df[filtered_columns]
        
        # Replace the original parquet file with the filtered DataFrame
        filtered_df.to_parquet(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 23
#      20 filtered_df = df[filtered_columns]
#      22 # Replace the original parquet file with the filtered DataFrame
# ---> 23 filtered_df.to_parquet(file_path, index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:2973, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2885 """
#    2886 Write a DataFrame to the binary parquet format.
#    2887
#    (...)
#    2969 >>> content = f.read()
#    2970 """
#    2971 from pandas.io.parquet import to_parquet
# -> 2973 return to_parquet(
#    2974     self,
#    2975     path,
#    2976     engine,
#    2977     compression=compression,
#    2978     index=index,
#    2979     partition_cols=partition_cols,
#    2980     storage_options=storage_options,
#    2981     **kwargs,
#    2982 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parquet.py:483, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     479 impl = get_engine(engine)
#     481 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 483 impl.write(
#     484     df,
#     485     path_or_buf,
#     486     compression=compression,
#     487     index=index,
#     488     partition_cols=partition_cols,
#     489     storage_options=storage_options,
#     490     filesystem=filesystem,
#     491     **kwargs,
#     492 )
#     494 if path is None:
#     495     assert isinstance(path_or_buf, io.BytesIO)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parquet.py:189, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     186 if index is not None:
#     187     from_pandas_kwargs["preserve_index"] = index
# --> 189 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     191 if df.attrs:
#     192     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/table.pxi:3874, in pyarrow.lib.Table.from_pandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/pandas_compat.py:570, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     562 def dataframe_to_arrays(df, schema, preserve_index, nthreads=1, columns=None,
#     563                         safe=True):
#     564     (all_names,
#     565      column_names,
#     566      index_column_names,
#     567      index_descriptors,
#     568      index_columns,
#     569      columns_to_convert,
# --> 570      convert_fields) = _get_columns_to_convert(df, schema, preserve_index,
#     571                                                columns)
#     573     # NOTE(wesm): If nthreads=None, then we use a heuristic to decide whether
#     574     # using a thread pool is worth it. Currently the heuristic is whether the
#     575     # nrows > 100 * ncols and ncols > 1.
#     576     if nthreads is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyarrow/pandas_compat.py:370, in _get_columns_to_convert(df, schema, preserve_index, columns)
#     367 convert_fields = []
#     369 for name in columns:
# --> 370     col = df[name]
#     371     name = _column_name_to_strings(name)
#     373     if _pandas_api.is_sparse(col):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3872, in DataFrame.__getitem__(self, key)
#    3865 # GH#45316 Return view if key is not duplicated
#    3866 # Only use drop_duplicates with duplicates for performance
#    3867 if not is_mi and (
#    3868     self.columns.is_unique
#    3869     and key in self.columns
#    3870     or key in self.columns.drop_duplicates(keep=False)
#    3871 ):
# -> 3872     return self._get_item_cache(key)
#    3874 elif is_mi and self.columns.is_unique and key in self.columns:
#    3875     return self._getitem_multilevel(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4418, in DataFrame._get_item_cache(self, item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
#    4417     loc = self.columns.get_loc(item)
# -> 4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#    4422     # for a chain
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3806, in DataFrame._ixs(self, i, axis)
#    3802 # icol
#    3803 else:
#    3804     label = self.columns[i]
# -> 3806     col_mgr = self._mgr.iget(i)
#    3807     result = self._box_col_values(col_mgr, i)
#    3809     # this is a cached value, mark it so
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1000, in BlockManager.iget(self, i, track_ref)
#     998 # shortcut for select a single-dim from a 2-dim BM
#     999 bp = BlockPlacement(slice(0, len(values)))
# -> 1000 nb = type(block)(
#    1001     values, placement=bp, ndim=1, refs=block.refs if track_ref else None
#    1002 )
#    1003 return SingleBlockManager(nb, self.axes[1])
#
# KeyboardInterrupt:

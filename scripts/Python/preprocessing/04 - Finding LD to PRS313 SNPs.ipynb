# %% [markdown]
# # Use LD Proxy API to find the relevant positions for each of the PRS313 SNPs

# %%
import requests
import pandas as pd
import os
import io


# API key
api_key = "ac16be4ad92d"

# Base URL for LDProxy API
base_url = "https://ldlink.nih.gov/LDlinkRest/ldproxy"

population = "ALL"

window = 1000000

r2_threshold = 0.01

# Read the chromosome positions from the text file
PRS313_LD = pd.read_excel("../../../Data/PRS313_with_23andMe.xlsx")

# %%
# Create a folder to store the CSV files
output_folder = "../../../Data/ld_variants"
os.makedirs(output_folder, exist_ok=True)

# Iterate over each position
for index, sample in PRS313_LD.iterrows():
    # if sample["in_23andMe"] == True:
    #      continue

    # Extract chromosome and position from the line
    chrom = sample["Chromosome"]
    pos = sample["Positionb"]
    
    # Construct the API request URL
    url = f"{base_url}?var={chrom}:{pos}&pop={population}&r2_d=r2&window={window}&genome_build=grch37&token={api_key}"
    
    # Send the API request
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
            # Create a StringIO object from the data
            data_io = io.StringIO(response.text)

            # Read the data into a DataFrame using read_csv
            df = pd.read_csv(data_io, sep='\\t')
            
            # # Filter variants with high LD scores (e.g., R2 >= 0.8)
            # high_ld_variants = df[df["R2"].astype(float) >= 0.8]
            
            # Generate a unique filename for the CSV file
            output_file = os.path.join(output_folder, f"{chrom}_{pos}.csv")
            
            # Save the high LD variants to a CSV file
            df.to_csv(output_file, index=False)
            
            print(f"Saved high LD variants for {chrom}:{pos} to {output_file}")
    else:
        print(f"Failed to retrieve data for {chrom}:{pos}. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 18
#      15 url = f"{base_url}?var={chrom}:{pos}&pop={population}&r2_d=r2&window={window}&genome_build=grch37&token={api_key}"
#      17 # Send the API request
# ---> 18 response = requests.get(url)
#      20 # Check if the request was successful
#      21 if response.status_code == 200:
#      22         # Create a StringIO object from the data
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import shutil

# Base folder where the CSV files are currently stored
base_folder = "../../../Data/ld_variants"

# Get a list of all CSV files in the base folder
csv_files = [f for f in os.listdir(base_folder) if f.endswith('.csv')]

# Iterate over each CSV file
for file in csv_files:
    # Extract the chromosome number from the file name
    chrom = file.split('_')[0]
    
    # Create a folder for the current chromosome if it doesn't exist
    chrom_folder = os.path.join(base_folder, f"chr{chrom}")
    os.makedirs(chrom_folder, exist_ok=True)
    
    # Move the file to the corresponding chromosome folder
    source_file = os.path.join(base_folder, file)
    destination_file = os.path.join(chrom_folder, file)
    shutil.move(source_file, destination_file)
    
    print(f"Moved {file} to {chrom_folder}")
# Out:
# Moved 6_152432902.csv to ../../../Data/ld_variants/chr6
# Moved 5_79180995.csv to ../../../Data/ld_variants/chr5
# Moved 7_25569548.csv to ../../../Data/ld_variants/chr7
# Moved 6_152055978.csv to ../../../Data/ld_variants/chr6
# Moved 5_44508264.csv to ../../../Data/ld_variants/chr5
# Moved 12_14413931.csv to ../../../Data/ld_variants/chr12
# Moved 4_106069013.csv to ../../../Data/ld_variants/chr4
# Moved 3_55970777.csv to ../../../Data/ld_variants/chr3
# Moved 3_59373745.csv to ../../../Data/ld_variants/chr3
# Moved 1_88156923.csv to ../../../Data/ld_variants/chr1
# Moved 6_16399557.csv to ../../../Data/ld_variants/chr6
# Moved 12_115796577.csv to ../../../Data/ld_variants/chr12
# Moved 5_131640536.csv to ../../../Data/ld_variants/chr5
# Moved 2_218292158.csv to ../../../Data/ld_variants/chr2
# Moved 10_38523626.csv to ../../../Data/ld_variants/chr10
# Moved 1_120257110.csv to ../../../Data/ld_variants/chr1
# Moved 8_106358620.csv to ../../../Data/ld_variants/chr8
# Moved 22_46283297.csv to ../../../Data/ld_variants/chr22
# Moved 3_141112859.csv to ../../../Data/ld_variants/chr3
# Moved 16_6963972.csv to ../../../Data/ld_variants/chr16
# Moved 5_71965007.csv to ../../../Data/ld_variants/chr5
# Moved 8_143669254.csv to ../../../Data/ld_variants/chr8
# Moved 22_39343916.csv to ../../../Data/ld_variants/chr22
# Moved 5_52679539.csv to ../../../Data/ld_variants/chr5
# Moved 22_38583315.csv to ../../../Data/ld_variants/chr22
# Moved 10_123340107.csv to ../../../Data/ld_variants/chr10
# Moved 22_40904707.csv to ../../../Data/ld_variants/chr22
# Moved 11_111696440.csv to ../../../Data/ld_variants/chr11
# Moved 5_32579616.csv to ../../../Data/ld_variants/chr5
# Moved 15_66630569.csv to ../../../Data/ld_variants/chr15
# Moved 1_114445880.csv to ../../../Data/ld_variants/chr1
# Moved 1_88428199.csv to ../../../Data/ld_variants/chr1
# Moved 16_23007047.csv to ../../../Data/ld_variants/chr16
# Moved 5_44619502.csv to ../../../Data/ld_variants/chr5
# Moved 22_19766137.csv to ../../../Data/ld_variants/chr22
# Moved 6_152023191.csv to ../../../Data/ld_variants/chr6
# Moved 15_100905819.csv to ../../../Data/ld_variants/chr15
# Moved 7_91459189.csv to ../../../Data/ld_variants/chr7
# Moved 6_82263549.csv to ../../../Data/ld_variants/chr6
# Moved 3_99403877.csv to ../../../Data/ld_variants/chr3
# Moved 2_217920769.csv to ../../../Data/ld_variants/chr2
# Moved 8_76333056.csv to ../../../Data/ld_variants/chr8
# Moved 12_115835836.csv to ../../../Data/ld_variants/chr12
# Moved 10_22861490.csv to ../../../Data/ld_variants/chr10
# Moved 1_202184600.csv to ../../../Data/ld_variants/chr1
# Moved 5_55662540.csv to ../../../Data/ld_variants/chr5
# Moved 8_124571581.csv to ../../../Data/ld_variants/chr8
# Moved 8_170692.csv to ../../../Data/ld_variants/chr8
# Moved 10_123349324.csv to ../../../Data/ld_variants/chr10
# Moved 4_38784633.csv to ../../../Data/ld_variants/chr4
# Moved 11_122966626.csv to ../../../Data/ld_variants/chr11
# Moved 6_152022664.csv to ../../../Data/ld_variants/chr6
# Moved 4_175842495.csv to ../../../Data/ld_variants/chr4
# Moved 15_67457698.csv to ../../../Data/ld_variants/chr15
# Moved 10_123095209.csv to ../../../Data/ld_variants/chr10
# Moved 15_46680811.csv to ../../../Data/ld_variants/chr15
# Moved 12_120832146.csv to ../../../Data/ld_variants/chr12
# Moved 1_121280613.csv to ../../../Data/ld_variants/chr1
# Moved 8_76230943.csv to ../../../Data/ld_variants/chr8
# Moved 20_52296849.csv to ../../../Data/ld_variants/chr20
# Moved 1_118141492.csv to ../../../Data/ld_variants/chr1
# Moved 1_168171052.csv to ../../../Data/ld_variants/chr1
# Moved 22_43433100.csv to ../../../Data/ld_variants/chr22
# Moved 11_69331418.csv to ../../../Data/ld_variants/chr11
# Moved 12_103097887.csv to ../../../Data/ld_variants/chr12
# Moved 11_1895708.csv to ../../../Data/ld_variants/chr11
# Moved 5_77155397.csv to ../../../Data/ld_variants/chr5
# Moved 3_172285237.csv to ../../../Data/ld_variants/chr3
# Moved 5_73234583.csv to ../../../Data/ld_variants/chr5
# Moved 2_172974566.csv to ../../../Data/ld_variants/chr2
# Moved 22_45319953.csv to ../../../Data/ld_variants/chr22
# Moved 2_88358825.csv to ../../../Data/ld_variants/chr2
# Moved 12_96027759.csv to ../../../Data/ld_variants/chr12
# Moved 18_29981526.csv to ../../../Data/ld_variants/chr18
# Moved 5_345109.csv to ../../../Data/ld_variants/chr5
# Moved 19_18569492.csv to ../../../Data/ld_variants/chr19
# Moved 1_110198129.csv to ../../../Data/ld_variants/chr1
# Moved 9_98362587.csv to ../../../Data/ld_variants/chr9
# Moved 5_122478676.csv to ../../../Data/ld_variants/chr5
# Moved 5_2777029.csv to ../../../Data/ld_variants/chr5
# Moved 19_46166073.csv to ../../../Data/ld_variants/chr19
# Moved 3_27388664.csv to ../../../Data/ld_variants/chr3
# Moved 2_202204741.csv to ../../../Data/ld_variants/chr2
# Moved 3_4742251.csv to ../../../Data/ld_variants/chr3
# Moved 6_18783140.csv to ../../../Data/ld_variants/chr6
# Moved 7_98005235.csv to ../../../Data/ld_variants/chr7
# Moved 16_53861592.csv to ../../../Data/ld_variants/chr16
# Moved 18_42888797.csv to ../../../Data/ld_variants/chr18
# Moved 13_73806982.csv to ../../../Data/ld_variants/chr13
# Moved 8_117209548.csv to ../../../Data/ld_variants/chr8
# Moved 10_13892298.csv to ../../../Data/ld_variants/chr10
# Moved 4_151218296.csv to ../../../Data/ld_variants/chr4
# Moved 6_87803819.csv to ../../../Data/ld_variants/chr6
# Moved 1_220671050.csv to ../../../Data/ld_variants/chr1
# Moved 7_28869017.csv to ../../../Data/ld_variants/chr7
# Moved 16_87086492.csv to ../../../Data/ld_variants/chr16
# Moved 11_803017.csv to ../../../Data/ld_variants/chr11
# Moved 12_85004551.csv to ../../../Data/ld_variants/chr12
# Moved 1_46670206.csv to ../../../Data/ld_variants/chr1
# Moved 13_32839990.csv to ../../../Data/ld_variants/chr13
# Moved 2_174212910.csv to ../../../Data/ld_variants/chr2
# Moved 11_433617.csv to ../../../Data/ld_variants/chr11
# Moved 4_89240476.csv to ../../../Data/ld_variants/chr4
# Moved 11_46318032.csv to ../../../Data/ld_variants/chr11
# Moved 10_5794652.csv to ../../../Data/ld_variants/chr10
# Moved 8_128213561.csv to ../../../Data/ld_variants/chr8
# Moved 6_20537845.csv to ../../../Data/ld_variants/chr6
# Moved 15_91512267.csv to ../../../Data/ld_variants/chr15
# Moved 2_121246568.csv to ../../../Data/ld_variants/chr2
# Moved 9_6880263.csv to ../../../Data/ld_variants/chr9
# Moved 1_41389220.csv to ../../../Data/ld_variants/chr1
# Moved 1_208076291.csv to ../../../Data/ld_variants/chr1
# Moved 12_111600134.csv to ../../../Data/ld_variants/chr12
# Moved 12_28149568.csv to ../../../Data/ld_variants/chr12
# Moved 17_43212339.csv to ../../../Data/ld_variants/chr17
# Moved 5_56045081.csv to ../../../Data/ld_variants/chr5
# Moved 10_115128491.csv to ../../../Data/ld_variants/chr10
# Moved 2_29615233.csv to ../../../Data/ld_variants/chr2
# Moved 16_4008542.csv to ../../../Data/ld_variants/chr16
# Moved 9_110885479.csv to ../../../Data/ld_variants/chr9
# Moved 5_122705244.csv to ../../../Data/ld_variants/chr5
# Moved 17_53209774.csv to ../../../Data/ld_variants/chr17
# Moved 12_29140260.csv to ../../../Data/ld_variants/chr12
# Moved 18_24337424.csv to ../../../Data/ld_variants/chr18
# Moved 11_42844441.csv to ../../../Data/ld_variants/chr11
# Moved 8_124739913.csv to ../../../Data/ld_variants/chr8
# Moved 8_29509616.csv to ../../../Data/ld_variants/chr8
# Moved 14_105213978.csv to ../../../Data/ld_variants/chr14
# Moved 17_44283858.csv to ../../../Data/ld_variants/chr17
# Moved 16_54682064.csv to ../../../Data/ld_variants/chr16
# Moved 14_37228504.csv to ../../../Data/ld_variants/chr14
# Moved 5_1353077.csv to ../../../Data/ld_variants/chr5
# Moved 15_50694306.csv to ../../../Data/ld_variants/chr15
# Moved 1_51467096.csv to ../../../Data/ld_variants/chr1
# Moved 4_143467195.csv to ../../../Data/ld_variants/chr4
# Moved 5_81512947.csv to ../../../Data/ld_variants/chr5
# Moved 18_24125857.csv to ../../../Data/ld_variants/chr18
# Moved 14_93070286.csv to ../../../Data/ld_variants/chr14
# Moved 2_10138983.csv to ../../../Data/ld_variants/chr2
# Moved 11_69330983.csv to ../../../Data/ld_variants/chr11
# Moved 11_65572431.csv to ../../../Data/ld_variants/chr11
# Moved 4_187503758.csv to ../../../Data/ld_variants/chr4
# Moved 7_55192256.csv to ../../../Data/ld_variants/chr7
# Moved 8_128372172.csv to ../../../Data/ld_variants/chr8
# Moved 1_100880328.csv to ../../../Data/ld_variants/chr1
# Moved 16_52599188.csv to ../../../Data/ld_variants/chr16
# Moved 11_108267402.csv to ../../../Data/ld_variants/chr11
# Moved 7_144048902.csv to ../../../Data/ld_variants/chr7
# Moved 1_149906413.csv to ../../../Data/ld_variants/chr1
# Moved 2_39699510.csv to ../../../Data/ld_variants/chr2
# Moved 8_23447496.csv to ../../../Data/ld_variants/chr8
# Moved 22_29203724.csv to ../../../Data/ld_variants/chr22
# Moved 8_102483100.csv to ../../../Data/ld_variants/chr8
# Moved 10_22032942.csv to ../../../Data/ld_variants/chr10
# Moved 11_116727936.csv to ../../../Data/ld_variants/chr11
# Moved 11_129243417.csv to ../../../Data/ld_variants/chr11
# Moved 1_18807339.csv to ../../../Data/ld_variants/chr1
# Moved 17_40485239.csv to ../../../Data/ld_variants/chr17
# Moved 12_57146069.csv to ../../../Data/ld_variants/chr12
# Moved 12_293626.csv to ../../../Data/ld_variants/chr12
# Moved 11_129461016.csv to ../../../Data/ld_variants/chr11
# Moved 3_27353716.csv to ../../../Data/ld_variants/chr3
# Moved 1_7917076.csv to ../../../Data/ld_variants/chr1
# Moved 8_120862186.csv to ../../../Data/ld_variants/chr8
# Moved 4_175847436.csv to ../../../Data/ld_variants/chr4
# Moved 16_80648296.csv to ../../../Data/ld_variants/chr16
# Moved 16_52538825.csv to ../../../Data/ld_variants/chr16
# Moved 17_77781725.csv to ../../../Data/ld_variants/chr17
# Moved 2_25129473.csv to ../../../Data/ld_variants/chr2
# Moved 14_37128564.csv to ../../../Data/ld_variants/chr14
# Moved 19_44283031.csv to ../../../Data/ld_variants/chr19
# Moved 3_29294845.csv to ../../../Data/ld_variants/chr3
# Moved 5_176134882.csv to ../../../Data/ld_variants/chr5
# Moved 5_58241712.csv to ../../../Data/ld_variants/chr5
# Moved 6_85912194.csv to ../../../Data/ld_variants/chr6
# Moved 11_103614438.csv to ../../../Data/ld_variants/chr11
# Moved 8_124563705.csv to ../../../Data/ld_variants/chr8
# Moved 6_151949806.csv to ../../../Data/ld_variants/chr6
# Moved 20_41613706.csv to ../../../Data/ld_variants/chr20
# Moved 20_11379842.csv to ../../../Data/ld_variants/chr20
# Moved 6_169006947.csv to ../../../Data/ld_variants/chr6
# Moved 16_10706580.csv to ../../../Data/ld_variants/chr16
# Moved 11_18664241.csv to ../../../Data/ld_variants/chr11
# Moved 1_217053815.csv to ../../../Data/ld_variants/chr1
# Moved 9_110837176.csv to ../../../Data/ld_variants/chr9
# Moved 7_101552440.csv to ../../../Data/ld_variants/chr7
# Moved 1_145604302.csv to ../../../Data/ld_variants/chr1
# Moved 2_121058254.csv to ../../../Data/ld_variants/chr2
# Moved 9_21964882.csv to ../../../Data/ld_variants/chr9
# Moved 2_241388857.csv to ../../../Data/ld_variants/chr2
# Moved 6_13713366.csv to ../../../Data/ld_variants/chr6
# Moved 7_99948655.csv to ../../../Data/ld_variants/chr7
# Moved 18_24518050.csv to ../../../Data/ld_variants/chr18
# Moved 12_70798355.csv to ../../../Data/ld_variants/chr12
# Moved 9_36928288.csv to ../../../Data/ld_variants/chr9
# Moved 5_90789470.csv to ../../../Data/ld_variants/chr5
# Moved 1_203770448.csv to ../../../Data/ld_variants/chr1
# Moved 21_16566350.csv to ../../../Data/ld_variants/chr21
# Moved 13_73960952.csv to ../../../Data/ld_variants/chr13
# Moved 10_64299890.csv to ../../../Data/ld_variants/chr10
# Moved 7_139943702.csv to ../../../Data/ld_variants/chr7
# Moved 11_69328130.csv to ../../../Data/ld_variants/chr11
# Moved 18_11696613.csv to ../../../Data/ld_variants/chr18
# Moved 10_80886726.csv to ../../../Data/ld_variants/chr10
# Moved 5_44649944.csv to ../../../Data/ld_variants/chr5
# Moved 17_40127060.csv to ../../../Data/ld_variants/chr17
# Moved 2_121159205.csv to ../../../Data/ld_variants/chr2
# Moved 21_47762932.csv to ../../../Data/ld_variants/chr21
# Moved 8_76378165.csv to ../../../Data/ld_variants/chr8
# Moved 1_10566215.csv to ../../../Data/ld_variants/chr1
# Moved 18_25407513.csv to ../../../Data/ld_variants/chr18
# Moved 7_94113799.csv to ../../../Data/ld_variants/chr7
# Moved 3_30684907.csv to ../../../Data/ld_variants/chr3
# Moved 3_46888198.csv to ../../../Data/ld_variants/chr3
# Moved 7_130674481.csv to ../../../Data/ld_variants/chr7
# Moved 22_29135543.csv to ../../../Data/ld_variants/chr22
# Moved 13_32972626.csv to ../../../Data/ld_variants/chr13
# Moved 10_123340431.csv to ../../../Data/ld_variants/chr10
# Moved 5_132407058.csv to ../../../Data/ld_variants/chr5
# Moved 14_91841069.csv to ../../../Data/ld_variants/chr14
# Moved 4_126752992.csv to ../../../Data/ld_variants/chr4
# Moved 8_128370949.csv to ../../../Data/ld_variants/chr8
# Moved 6_21923810.csv to ../../../Data/ld_variants/chr6
# Moved 9_110303808.csv to ../../../Data/ld_variants/chr9
# Moved 5_1296255.csv to ../../../Data/ld_variants/chr5
# Moved 9_129424719.csv to ../../../Data/ld_variants/chr9
# Moved 5_56023083.csv to ../../../Data/ld_variants/chr5
# Moved 9_119313486.csv to ../../../Data/ld_variants/chr9
# Moved 10_80851257.csv to ../../../Data/ld_variants/chr10
# Moved 9_110849525.csv to ../../../Data/ld_variants/chr9
# Moved 16_4106788.csv to ../../../Data/ld_variants/chr16
# Moved 5_44706498.csv to ../../../Data/ld_variants/chr5
# Moved 22_29121087.csv to ../../../Data/ld_variants/chr22
# Moved 10_22477776.csv to ../../../Data/ld_variants/chr10
# Moved 12_28174817.csv to ../../../Data/ld_variants/chr12
# Moved 6_43227141.csv to ../../../Data/ld_variants/chr6
# Moved 17_29168077.csv to ../../../Data/ld_variants/chr17
# Moved 9_136146597.csv to ../../../Data/ld_variants/chr9
# Moved 1_242034263.csv to ../../../Data/ld_variants/chr1
# Moved 9_87782211.csv to ../../../Data/ld_variants/chr9
# Moved 7_21940960.csv to ../../../Data/ld_variants/chr7
# Moved 11_65553492.csv to ../../../Data/ld_variants/chr11
# Moved 17_39251123.csv to ../../../Data/ld_variants/chr17
# Moved 5_104300273.csv to ../../../Data/ld_variants/chr5
# Moved 2_217955896.csv to ../../../Data/ld_variants/chr2
# Moved 19_13249921.csv to ../../../Data/ld_variants/chr19
# Moved 11_44368892.csv to ../../../Data/ld_variants/chr11
# Moved 10_95292187.csv to ../../../Data/ld_variants/chr10
# Moved 17_40744470.csv to ../../../Data/ld_variants/chr17
# Moved 16_85145977.csv to ../../../Data/ld_variants/chr16
# Moved 6_151955914.csv to ../../../Data/ld_variants/chr6
# Moved 3_71620370.csv to ../../../Data/ld_variants/chr3
# Moved 16_53809123.csv to ../../../Data/ld_variants/chr16
# Moved 6_170332621.csv to ../../../Data/ld_variants/chr6
# Moved 6_149595505.csv to ../../../Data/ld_variants/chr6
# Moved 7_102481842.csv to ../../../Data/ld_variants/chr7
# Moved 5_16231194.csv to ../../../Data/ld_variants/chr5
# Moved 14_68660428.csv to ../../../Data/ld_variants/chr14
# Moved 3_49709912.csv to ../../../Data/ld_variants/chr3
# Moved 4_92594859.csv to ../../../Data/ld_variants/chr4
# Moved 10_71335574.csv to ../../../Data/ld_variants/chr10
# Moved 1_41380440.csv to ../../../Data/ld_variants/chr1
# Moved 21_16364756.csv to ../../../Data/ld_variants/chr21
# Moved 13_43501356.csv to ../../../Data/ld_variants/chr13
# Moved 8_36858483.csv to ../../../Data/ld_variants/chr8
# Moved 8_17787610.csv to ../../../Data/ld_variants/chr8
# Moved 2_192381934.csv to ../../../Data/ld_variants/chr2
# Moved 9_22041998.csv to ../../../Data/ld_variants/chr9
# Moved 6_27425644.csv to ../../../Data/ld_variants/chr6
# Moved 19_19517054.csv to ../../../Data/ld_variants/chr19
# Moved 21_16574455.csv to ../../../Data/ld_variants/chr21
# Moved 10_64819996.csv to ../../../Data/ld_variants/chr10
# Moved 12_83064195.csv to ../../../Data/ld_variants/chr12
# Moved 4_84370124.csv to ../../../Data/ld_variants/chr4
# Moved 19_17393925.csv to ../../../Data/ld_variants/chr19
# Moved 3_189774456.csv to ../../../Data/ld_variants/chr3
# Moved 5_1279790.csv to ../../../Data/ld_variants/chr5
# Moved 2_121089731.csv to ../../../Data/ld_variants/chr2
# Moved 10_114777670.csv to ../../../Data/ld_variants/chr10
# Moved 7_130656911.csv to ../../../Data/ld_variants/chr7
# Moved 3_63887449.csv to ../../../Data/ld_variants/chr3
# Moved 2_70172587.csv to ../../../Data/ld_variants/chr2
# Moved 16_53861139.csv to ../../../Data/ld_variants/chr16
# Moved 2_19315675.csv to ../../../Data/ld_variants/chr2
# Moved 12_115108136.csv to ../../../Data/ld_variants/chr12
# Moved 18_20634253.csv to ../../../Data/ld_variants/chr18
# Moved 20_5948227.csv to ../../../Data/ld_variants/chr20
# Moved 1_217220574.csv to ../../../Data/ld_variants/chr1
# Moved 5_173358154.csv to ../../../Data/ld_variants/chr5
# Moved 3_87037543.csv to ../../../Data/ld_variants/chr3
# Moved 14_68979835.csv to ../../../Data/ld_variants/chr14
# Moved 2_29179452.csv to ../../../Data/ld_variants/chr2
# Moved 1_155556971.csv to ../../../Data/ld_variants/chr1
# Moved 19_55816678.csv to ../../../Data/ld_variants/chr19
# Moved 1_201437832.csv to ../../../Data/ld_variants/chr1
# Moved 18_42411803.csv to ../../../Data/ld_variants/chr18
# Moved 5_169591460.csv to ../../../Data/ld_variants/chr5
# Moved 1_204502514.csv to ../../../Data/ld_variants/chr1
# Moved 22_29551872.csv to ../../../Data/ld_variants/chr22
# Moved 2_218714845.csv to ../../../Data/ld_variants/chr2
# Moved 8_23663653.csv to ../../../Data/ld_variants/chr8
# Moved 8_129199566.csv to ../../../Data/ld_variants/chr8
# Moved 9_110837073.csv to ../../../Data/ld_variants/chr9
# Moved 15_75750383.csv to ../../../Data/ld_variants/chr15
# Moved 5_44853593.csv to ../../../Data/ld_variants/chr5
# Moved 5_158244083.csv to ../../../Data/ld_variants/chr5
# Moved 5_56042972.csv to ../../../Data/ld_variants/chr5
# Moved 14_91751788.csv to ../../../Data/ld_variants/chr14
# Moved 6_130341728.csv to ../../../Data/ld_variants/chr6
# Moved 1_172328767.csv to ../../../Data/ld_variants/chr1
# Moved 1_121287994.csv to ../../../Data/ld_variants/chr1
# Moved 5_55965167.csv to ../../../Data/ld_variants/chr5
# Moved 12_28347382.csv to ../../../Data/ld_variants/chr12

# %% [markdown]
# # Find overlap b/w 23AndMe and LD

# %%
import os
import pandas as pd
import re
import numpy as np

import collections


directory = "../../../Data/ld_variants"

# Create a folder to store the CSV files
output_folder = "../../../Data/ld_variants"
os.makedirs(output_folder, exist_ok=True)

def extract_coord_alleles(col_name):
    match = re.search(r'chr(\d+)_(\d+)_([ACGT])_([ACGT])$', col_name)
    if match:
        chr_num, position, ref_allele, alt_allele = match.groups()
        return f'chr{chr_num}:{position}', f'({ref_allele}/{alt_allele})'
    return None, None

# Create an empty list to store the matching variants across all chromosomes
matching_variants_all = []

training_data_folder = "../../../Data/Raw_training_data_23andMe_union/"
output_folder = "../../../Data/Data/Filtered_raw_training_data_union/"

# Iterate over each chromosome folder
for chrom_folder in os.listdir(directory):
    if chrom_folder.startswith("chr"):
        chrom = chrom_folder[3:]
        files_folder = os.path.join(directory, chrom_folder)

        # Load the training data for the chromosome
        training_data = pd.read_parquet(f"{training_data_folder}23AndMe_PRS313_merged_chr{chrom}.parquet")

        matching_columns = []
        matching_variants_chrom = []
        not_found_snps_chrom = []

        for filename in os.listdir(files_folder):
            if filename.endswith(".csv"):
                PRS313_SNP_pos = filename.split('.')[0]
                position_column = training_data.columns[training_data.columns.str.contains(PRS313_SNP_pos)]


                try:
                    variants = pd.read_csv(os.path.join(files_folder, filename))

                    for column in training_data.columns:
                        coord, alleles = extract_coord_alleles(column)

                        if coord is not None and alleles is not None:
                            mask = (variants['Coord'] == coord & (variants['Alleles'] == alleles))

                            if mask.any():
                                if column not in matching_columns:
                                    matching_columns.append(column)
                                    matching_variants_chrom.append(variants[mask])
                except KeyError:
                    error_position = filename.split('.')[0]
                    not_found_snps_chrom.append(error_position)
                    print(f"SNP {error_position} not found in dbSNP and cannot be proxied using LDProxy")

                    counter_error_added = 0
                    for col in training_data.columns:
                        coord, _ = extract_coord_alleles(col)
                        if coord is not None:
                            col_position = int(coord.split(':')[1])
                            error_bp = int(error_position.split('_')[1])
                            if abs(col_position - error_bp) <= 500000 and col not in matching_columns:
                                counter_error_added += 1
                                
                                coord, alleles = extract_coord_alleles(col)

                                if coord is not None and alleles is not None:
                                    matching_columns.append(col)

                                    empty_structure = pd.DataFrame({
                                        'RS_Number': [np.nan],
                                        'Coord': coord,
                                        'Alleles': alleles,
                                        'MAF': [np.nan],
                                        'Distance': [np.nan],
                                        'Dprime': [np.nan],
                                        'R2': [np.nan],
                                        'Correlated_Alleles': [np.nan],
                                        'FORGEdb': [np.nan],
                                        'RegulomeDB': [np.nan],
                                        'Function': [np.nan]
                                    })
                                    matching_variants_chrom.append(empty_structure)
    
                    print(f"Added {counter_error_added} columns to matching_columns for missing data position: {error_position}")

        matching_data = training_data[matching_columns]

        os.makedirs(output_folder, exist_ok=True)
        save_path = f"{output_folder}/23AndMe_PRS313_merged_chr{chrom}_matching.parquet"
        matching_data.to_parquet(save_path)

        matching_variants_chrom_df = pd.concat(matching_variants_chrom, ignore_index=True)
        matching_variants_all.append(matching_variants_chrom_df)

        print(f"Saved to file {save_path}")
        print(f"Found {len(matching_columns)} matching columns")
        print(f"Found {len(matching_variants_chrom_df)} matching variants")
        if (len(matching_columns) != len(matching_variants_chrom_df)):
            duplicates = [item for item, count in collections.Counter(matching_variants_chrom_df.Coord).items() if count > 1]
            matching_variants_chrom_df.loc[matching_variants_chrom_df.Coord.isin(duplicates)]
            print("SOMETHIGN HAS GONE WRONG")

matching_variants_all_df = pd.concat(matching_variants_all, ignore_index=True)
matching_variants_all_df.to_csv(f"{output_folder}/23AndMe_matching_variants.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 35
#      32 files_folder = os.path.join(directory, chrom_folder)
#      34 # Load the training data for the chromosome
# ---> 35 training_data = pd.read_parquet(f"{training_data_folder}23AndMe_PRS313_merged_chr{chrom}.parquet")
#      37 matching_columns = []
#      38 matching_variants_chrom = []
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:281, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
# --> 281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#     284         result = result._as_manager("array", copy=False)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pyarrow/array.pxi:872, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pyarrow/table.pxi:4904, in pyarrow.lib.Table._to_pandas()
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pyarrow/pandas_compat.py:779, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     776 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     778 column_names = table.column_names
# --> 779 result = pa.lib.table_to_blocks(options, table, categories,
#     780                                 list(ext_columns_dtypes.keys()))
#     781 if _pandas_api.is_ge_v3():
#     782     from pandas.api.internals import create_dataframe_from_blocks
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import re
import numpy as np

directory = "../../../Data/ld_variants"

# Create a folder to store the CSV files
output_folder = "../../../Data/ld_variants"
os.makedirs(output_folder, exist_ok=True)

# # Regex used to parse the 23andMe data. Can't use this version because it looks for locations where there are more than one nucleotide in the ref/alt alleles
# def extract_coord_alleles(col_name):
#     match = re.search(r'chr(\d+)_(\d+)_([ACGT,]+)_([ACGT,]+)', col_name)
#     if match:
#         chr_num, position, ref_allele, alt_allele = match.groups()
#         return f'chr{chr_num}:{position}', f'({ref_allele}/{alt_allele})'
#     return None, None

# Only gets the 23andMe data with a single nucleotide for ref/alt 
def extract_coord_alleles(col_name):
    match = re.search(r'chr(\d+)_(\d+)_([ACGT])_([ACGT])$', col_name)
    if match:
        chr_num, position, ref_allele, alt_allele = match.groups()
        return f'chr{chr_num}:{position}', f'({ref_allele}/{alt_allele})'
    return None, None

# Create an empty list to store the matching variants across all chromosomes
matching_columns_all = []

training_data_folder = "../../../Data/Raw_training_data_23andMe_union/"
output_folder = "../../../Data/Filtered_raw_training_data_union/"
no_ld_positions = 0

# Iterate over each chromosome folder
for chrom_folder in os.listdir(directory):
    if chrom_folder.startswith("chr"):
        chrom = chrom_folder[3:]
        files_folder = os.path.join(directory, chrom_folder)

        # Load the training data for the chromosome
        training_data = pd.read_parquet(f"{training_data_folder}23AndMe_PRS313_merged_chr{chrom}.parquet")

        # Extract positions from training_data.columns
        training_coords = training_data.columns.to_series().apply(lambda col: extract_coord_alleles(col)[0])
        training_coords.name = "Coord"

        matching_columns = []
        not_found_snps_chrom = []

        for filename in os.listdir(files_folder):
            if filename.endswith(".csv"):
                
                # Use to add PRS313 SNPs to the training data, since the regex in extract_coord_alleles will no longer match multiallelic/indels for mutations
                position = filename.split('.')[0]
                position_column = training_data.columns[training_data.columns.str.contains(position)]
                if (len(position_column) > 1):
                    raise Exception("More than 1 PRS313 SNP")
                # Add position_columnt o matching_columns if it isn't in there
                if (position_column not in matching_columns):
                    matching_columns.append(position_column[0])

                try:
                    variants = pd.read_csv(os.path.join(files_folder, filename))

                    # Find matching columns based on coordinates
                    matched_columns = training_coords[training_coords.isin(variants['Coord'].values)].index.tolist()
                    matching_columns.extend([str(col) for col in matched_columns if col not in matching_columns])

                except KeyError:
                    error_position = filename.split('.')[0]
                    not_found_snps_chrom.append(error_position)
                    no_ld_positions+=1
                    # Find close columns using the training_coords
                    error_bp = int(error_position.split('_')[1])
                    close_coords = training_coords[training_coords.apply(lambda coord: coord is not None and abs(int(coord.split(':')[1]) - error_bp) <= 500000)]
                    close_cols = close_coords.index.tolist()
                    matching_columns.extend([str(col) for col in close_cols if col not in matching_columns])

                    print(f"Added {len(close_cols)} columns to matching_columns for missing data position: {error_position}")

        # Append matching columns for the current chromosome to the overall list
        matching_columns_all.extend(matching_columns)

        matching_data = training_data[matching_columns]

        os.makedirs(output_folder, exist_ok=True)
        save_path = f"{output_folder}23AndMe_PRS313_merged_chr{chrom}_matching.parquet"
        matching_data.to_parquet(save_path)

        print(f"Saved to file {save_path}")
        print(f"Found {len(matching_columns)} matching columns for chromosome {chrom}")

# Save the list of all matching columns to a CSV file
matching_columns_df = pd.DataFrame({'matching_columns': matching_columns_all})
matching_columns_df.to_csv(f"{output_folder}/matching_columns_all.csv", index=False)

print("All processing done and matching columns saved to CSV.")
# Out:
# Added 204 columns to matching_columns for missing data position: 12_83064195
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr12_matching.parquet
# Found 852 matching columns for chromosome 12
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr15_matching.parquet
# Found 310 matching columns for chromosome 15
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr14_matching.parquet
# Found 459 matching columns for chromosome 14
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr13_matching.parquet
# Found 152 matching columns for chromosome 13
# Added 209 columns to matching_columns for missing data position: 22_38583315
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr22_matching.parquet
# Found 542 matching columns for chromosome 22
# Added 167 columns to matching_columns for missing data position: 4_151218296
# Added 412 columns to matching_columns for missing data position: 4_187503758
# Added 212 columns to matching_columns for missing data position: 4_126752992
# Added 200 columns to matching_columns for missing data position: 4_84370124
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr4_matching.parquet
# Found 1488 matching columns for chromosome 4
# Added 206 columns to matching_columns for missing data position: 3_55970777
# Added 258 columns to matching_columns for missing data position: 3_63887449
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr3_matching.parquet
# Found 1255 matching columns for chromosome 3
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr2_matching.parquet
# Found 1044 matching columns for chromosome 2
# Added 154 columns to matching_columns for missing data position: 5_44508264
# Added 216 columns to matching_columns for missing data position: 5_52679539
# Added 215 columns to matching_columns for missing data position: 5_32579616
# Added 182 columns to matching_columns for missing data position: 5_81512947
# Added 179 columns to matching_columns for missing data position: 5_176134882
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr5_matching.parquet
# Found 2038 matching columns for chromosome 5
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr18_matching.parquet
# Found 589 matching columns for chromosome 18
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr20_matching.parquet
# Found 108 matching columns for chromosome 20
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr16_matching.parquet
# Found 606 matching columns for chromosome 16
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr11_matching.parquet
# Found 1275 matching columns for chromosome 11
# Added 180 columns to matching_columns for missing data position: 10_22861490
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr10_matching.parquet
# Found 942 matching columns for chromosome 10
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr17_matching.parquet
# Found 380 matching columns for chromosome 17
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr21_matching.parquet
# Found 94 matching columns for chromosome 21
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr19_matching.parquet
# Found 348 matching columns for chromosome 19
# Added 177 columns to matching_columns for missing data position: 7_91459189
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr7_matching.parquet
# Found 735 matching columns for chromosome 7
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr9_matching.parquet
# Found 653 matching columns for chromosome 9
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr8_matching.parquet
# Found 799 matching columns for chromosome 8
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr6_matching.parquet
# Found 853 matching columns for chromosome 6
# Added 177 columns to matching_columns for missing data position: 1_100880328
# Added 320 columns to matching_columns for missing data position: 1_10566215
# Saved to file ../../../Data/Filtered_raw_training_data_union/23AndMe_PRS313_merged_chr1_matching.parquet
# Found 2028 matching columns for chromosome 1
# All processing done and matching columns saved to CSV.

# %%
all_pos = "../../../Data/Data/Filtered_raw_training_data_union/matching_columns_all.csv"
missing_pos = "../../../Data/Filtered_raw_training_data_union/matching_columns_all.csv"

all_pos = pd.read_csv(all_pos)
missing_pos = pd.read_csv(missing_pos)
missing_columns = set(missing_pos["matching_columns"])
all_columns = set(all_pos["matching_columns"])
difference = all_columns.difference(missing_columns)
difference
# Out:
# {'chr10_123340431_GC_G_PRS313_Unknown',
#  'chr10_95292187_CAA_C_PRS313_Unknown',
#  'chr14_91751788_TC_T_PRS313_Unknown',
#  'chr16_4008542_CAAAAA_C_PRS313_Unknown',
#  'chr18_24518050_AT_A_PRS313_Unknown',
#  'chr1_110198129_CAAA_C_PRS313_Unknown',
#  'chr1_168171052_CA_C_PRS313_Unknown',
#  'chr1_46670206_TC_T_PRS313_Unknown',
#  'chr1_51467096_CT_C_PRS313_Unknown',
#  'chr22_40904707_CT_C_PRS313_Unknown',
#  'chr2_217955896_GA_G_PRS313_Unknown',
#  'chr3_141112859_CTT_C_PRS313_Unknown',
#  'chr4_92594859_TTCTTTC_T_PRS313_Unknown',
#  'chr5_77155397_GT_G_PRS313_Unknown',
#  'chr6_152022664_CAAAAAAA_C_PRS313_Unknown',
#  'chr6_20537845_CA_C_PRS313_Unknown',
#  'chr6_82263549_AAT_A_PRS313_Unknown',
#  'chr6_85912194_CAA_C_PRS313_Unknown',
#  'chr7_139943702_CT_C_PRS313_Unknown',
#  'chr8_17787610_CT_C_PRS313_Unknown',
#  'chr9_110303808_TAA_T_PRS313_Unknown',
#  'chr9_21964882_CAAAA_C_PRS313_Unknown'}

# %%
missing_pos.loc[missing_pos["matching_columns"].str.contains("PRS313")][50:100]
# Out:
#                                matching_columns
# 2793    chr4_151218296_CATATTT_C_PRS313_Unknown
# 2913           chr4_89240476_G_A_PRS313_Unknown
# 2941          chr4_143467195_C_T_PRS313_Unknown
# 3376        chr4_187503758_A_G,T_PRS313_Unknown
# 3626  chr4_126752992_A_AAT,AATAT_PRS313_Unknown
# 3874      chr4_84370124_TAA_TA,T_PRS313_Unknown
# 4085          chr3_55970777_A_AT_PRS313_Unknown
# 4112           chr3_59373745_C_T_PRS313_Unknown
# 4335           chr3_99403877_G_A_PRS313_Unknown
# 4345            chr3_172285237_G_A_PRS313_Known
# 4402             chr3_27353716_C_A_PRS313_Known
# 4413           chr3_27388664_C_G_PRS313_Unknown
# 4450            chr3_4742251_A_G_PRS313_Unknown
# 4533           chr3_29294845_C_T_PRS313_Unknown
# 4574           chr3_30684907_C_T_PRS313_Unknown
# 4621           chr3_46888198_T_C_PRS313_Unknown
# 4721           chr3_71620370_T_G_PRS313_Unknown
# 4799          chr3_49709912_C_CT_PRS313_Unknown
# 4830          chr3_189774456_C_T_PRS313_Unknown
# 5093   chr3_63887449_T_TTG,TTGTG_PRS313_Unknown
# 5107             chr3_87037543_A_G_PRS313_Known
# 5169          chr2_218292158_C_G_PRS313_Unknown
# 5272            chr2_217920769_G_T_PRS313_Known
# 5347          chr2_172974566_C_G_PRS313_Unknown
# 5360           chr2_88358825_G_C_PRS313_Unknown
# 5432          chr2_202204741_T_C_PRS313_Unknown
# 5466          chr2_174212910_A_G_PRS313_Unknown
# 5486          chr2_121246568_T_C_PRS313_Unknown
# 5547           chr2_29179452_G_C_PRS313_Unknown
# 5548           chr2_29615233_T_C_PRS313_Unknown
# 5579           chr2_10138983_T_C_PRS313_Unknown
# 5682          chr2_39699510_C_CT_PRS313_Unknown
# 5730             chr2_25129473_A_G_PRS313_Known
# 5830          chr2_121058254_A_G_PRS313_Unknown
# 5838          chr2_241388857_C_A_PRS313_Unknown
# 5894          chr2_121159205_G_A_PRS313_Unknown
# 5910            chr2_192381934_C_T_PRS313_Known
# 5954            chr2_121089731_T_C_PRS313_Known
# 5991           chr2_70172587_G_A_PRS313_Unknown
# 6047           chr2_19315675_T_A_PRS313_Unknown
# 6182          chr2_218714845_G_A_PRS313_Unknown
# 6222          chr5_79180995_G_GA_PRS313_Unknown
# 6290             chr5_44649944_C_T_PRS313_Known
# 6299             chr5_44706498_A_G_PRS313_Known
# 6387           chr5_44853593_G_C_PRS313_Unknown
# 6388          chr5_44508264_G_GT_PRS313_Unknown
# 6389           chr5_44619502_A_G_PRS313_Unknown
# 6473          chr5_131640536_A_G_PRS313_Unknown
# 6510           chr5_71965007_G_A_PRS313_Unknown
# 6735      chr5_52679539_C_CA,CAA_PRS313_Unknown

# %% [markdown]
# # Optional - Create Final Training Data with +/- 500K BP Window

# %%
import os
import pandas as pd
import re

window_size = 250000
pattern = re.compile(r"chr\d+_(\d+)_")

# Create an empty list to store the matching variants across all chromosomes
matching_variants_all = []

output_dir = "../../../Data/500k_window_filtered_data"

os.makedirs(output_dir, exist_ok=True)

for chrom in range(1, 23):
    # Load the training data for the chromosome
    training_data = pd.read_parquet(f"../../../Data/Raw_training_data_23andMe_union/23AndMe_PRS313_merged_chr{chrom}.parquet")
    
    # Get all columns with "PRS313" in the name
    prs313_unknown_columns = [col for col in training_data.columns if "PRS313_Unknown" in col]
    prs313_unknown_positions = [int(pattern.search(col).group(1)) for col in prs313_unknown_columns]
    prs313_unknown_positions_set = set(prs313_unknown_positions)
    
    # Get all columns in training_data that contain a number within +/- 500k of the PRS313_Unknown position
    filtered_columns = [col for col in training_data.columns if any(abs(int(pattern.search(col).group(1)) - pos) <= window_size for pos in prs313_unknown_positions_set)]
    
    training_data_filtered = training_data[filtered_columns]

    print(len(filtered_columns))



    # Save the filtered training data for the chromosome
    training_data_filtered.to_parquet(f"{output_dir}/23AndMe_PRS313_merged_chr{chrom}_filtered.parquet")
# Out:
# 2237
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 28
#      25 print(len(filtered_columns))
#      27 # Save the filtered training data for the chromosome
# ---> 28 training_data_filtered.to_parquet(f"../../Data/500k_window_filtered_data/23AndMe_PRS313_merged_chr{chrom}_filtered.parquet")
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/core/frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:198, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     195     merged_metadata = {**existing_metadata, **df_metadata}
#     196     table = table.replace_schema_metadata(merged_metadata)
# --> 198 path_or_handle, handles, filesystem = _get_path_or_handle(
#     199     path,
#     200     filesystem,
#     201     storage_options=storage_options,
#     202     mode="wb",
#     203     is_dir=partition_cols is not None,
#     204 )
#     205 if (
#     206     isinstance(path_or_handle, io.BufferedWriter)
#     207     and hasattr(path_or_handle, "name")
#     208     and isinstance(path_or_handle.name, (str, bytes))
#     209 ):
#     210     if isinstance(path_or_handle.name, bytes):
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/Documents/medicaid/DeepImpute/.venv/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../../Data/500k_window_filtered_data'

# %%
import pandas as pd
chrom = 1

# training_data_window = pd.read_parquet(f"../../../Data/500k_window_filtered_data/23AndMe_PRS313_merged_chr{chrom}_filtered.parquet")
# print(training_data_window.shape)

training_data_ld_proxy = pd.read_parquet(f"../../../Data/Filtered_unphased_training_data_union_final/23AndMe_PRS313_merged_chr{chrom}_matching_combined.parquet")
print(training_data_ld_proxy.shape)
# Out:
# (2504, 2028)

# %%
training_data_ld_proxy
# Out:
#          chr1_88156923_G_A_PRS313_Known_combined  chr1_88177403_G_A_combined  \
# HG00096                                        1                           0
# HG00097                                        1                           1
# HG00099                                        0                           2
# HG00100                                        0                           2
# HG00101                                        2                           1
# ...                                          ...                         ...
# NA21137                                        0                           0
# NA21141                                        0                           0
# NA21142                                        0                           0
# NA21143                                        0                           2
# NA21144                                        0                           2
#
#          chr1_88127152_T_C_combined  chr1_88208135_G_A_combined  \
# HG00096                           0                           0
# HG00097                           0                           0
# HG00099                           0                           0
# HG00100                           0                           0
# HG00101                           0                           0
# ...                             ...                         ...
# NA21137                           0                           2
# NA21141                           0                           1
# NA21142                           0                           0
# NA21143                           0                           0
# NA21144                           0                           1
#
#          chr1_88109828_G_A_combined  chr1_88086894_C_A_combined  \
# HG00096                           2                           1
# HG00097                           1                           0
# HG00099                           1                           1
# HG00100                           1                           1
# HG00101                           0                           0
# ...                             ...                         ...
# NA21137                           2                           2
# NA21141                           1                           1
# NA21142                           1                           2
# NA21143                           1                           2
# NA21144                           1                           1
#
#          chr1_88091734_C_T_combined  chr1_88116467_A_C_combined  \
# HG00096                           2                           0
# HG00097                           1                           1
# HG00099                           1                           1
# HG00100                           1                           1
# HG00101                           0                           1
# ...                             ...                         ...
# NA21137                           2                           0
# NA21141                           1                           1
# NA21142                           1                           1
# NA21143                           2                           0
# NA21144                           1                           0
#
#          chr1_88073752_G_T_combined  chr1_88120134_T_C_combined  ...  \
# HG00096                           0                           2  ...
# HG00097                           0                           2  ...
# HG00099                           0                           2  ...
# HG00100                           0                           2  ...
# HG00101                           1                           2  ...
# ...                             ...                         ...  ...
# NA21137                           0                           2  ...
# NA21141                           0                           2  ...
# NA21142                           0                           2  ...
# NA21143                           0                           2  ...
# NA21144                           0                           2  ...
#
#          chr1_172632057_A_G_combined  chr1_172627498_C_T_combined  \
# HG00096                            2                            0
# HG00097                            0                            0
# HG00099                            2                            1
# HG00100                            2                            1
# HG00101                            0                            0
# ...                              ...                          ...
# NA21137                            2                            2
# NA21141                            1                            1
# NA21142                            1                            0
# NA21143                            1                            1
# NA21144                            2                            2
#
#          chr1_172464519_T_G_combined  \
# HG00096                            2
# HG00097                            1
# HG00099                            2
# HG00100                            2
# HG00101                            1
# ...                              ...
# NA21137                            2
# NA21141                            2
# NA21142                            2
# NA21143                            2
# NA21144                            2
#
#          chr1_121287994_A_G_PRS313_Unknown_combined  \
# HG00096                                           0
# HG00097                                           0
# HG00099                                           0
# HG00100                                           1
# HG00101                                           0
# ...                                             ...
# NA21137                                           0
# NA21141                                           1
# NA21142                                           1
# NA21143                                           1
# NA21144                                           0
#
#          chr1_120687115_G_A_combined  chr1_120690218_C_T_combined  \
# HG00096                            2                            2
# HG00097                            2                            2
# HG00099                            2                            2
# HG00100                            2                            2
# HG00101                            2                            2
# ...                              ...                          ...
# NA21137                            2                            2
# NA21141                            1                            0
# NA21142                            1                            1
# NA21143                            2                            2
# NA21144                            2                            2
#
#          chr1_121280485_A_G_combined  chr1_120689085_C_T_combined  \
# HG00096                            0                            2
# HG00097                            0                            2
# HG00099                            0                            2
# HG00100                            1                            2
# HG00101                            0                            2
# ...                              ...                          ...
# NA21137                            0                            2
# NA21141                            0                            1
# NA21142                            0                            1
# NA21143                            0                            2
# NA21144                            0                            2
#
#          chr1_121137155_A_G_combined  chr1_120405606_T_C_combined
# HG00096                            0                            0
# HG00097                            0                            0
# HG00099                            0                            0
# HG00100                            0                            0
# HG00101                            0                            0
# ...                              ...                          ...
# NA21137                            0                            0
# NA21141                            0                            0
# NA21142                            0                            0
# NA21143                            0                            0
# NA21144                            0                            0
#
# [2504 rows x 2028 columns]

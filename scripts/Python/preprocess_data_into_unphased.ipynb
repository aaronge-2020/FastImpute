# %%
import torch
import pandas as pd
import numpy as np
from torch.utils.data import TensorDataset, random_split, DataLoader
import os

# Set a random seed for reproducibility
torch.manual_seed(42)

folder_dir = "../../Data/Filtered_training_data_union/"
output_dir = "../../Data/Filtered_unphased_training_data/"
os.makedirs(output_dir, exist_ok=True)

chromosome_number = 1
for chromosome_number in range(chromosome_number, 23):
    file_dir = folder_dir + f"23AndMe_PRS313_merged_chr{chromosome_number}_matching.parquet"
    
    # Load your data into a pandas DataFrame
    data = pd.read_parquet(file_dir)
    
    # Combine haplotypes by adding them together
    new_cols = []
    for col in data.columns:
        combined_col = f"{col}_combined"
        new_cols.append(combined_col)
        data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
    
    # Reorder the columns
    data = data[new_cols]
    
    # Convert all the values to booleans
    data = data.astype(bool)
    data.dtypes
    
    # Save the dataframe
    output_file = output_dir + f"23AndMe_PRS313_merged_chr{chromosome_number}_matching_combined.parquet"
    data.to_parquet(output_file)
# Out:
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# ...
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# /var/folders/yg/982c10113957_2gb06y92y35sx509h/T/ipykernel_59552/3521667169.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chr1_204438643_G_T_combined'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4264, in DataFrame._set_item_mgr(self, key, value, refs)
#    4263 try:
# -> 4264     loc = self._info_axis.get_loc(key)
#    4265 except KeyError:
#    4266     # This item wasn't present, just insert at end
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#
# KeyError: 'chr1_204438643_G_T_combined'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 26
#      24     combined_col = f"{col}_combined"
#      25     new_cols.append(combined_col)
# ---> 26     data[combined_col] = [sum(map(int, allele.split("|"))) for allele in data[col]]
#      28 # Reorder the columns
#      29 data = data[new_cols]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4317, in DataFrame._set_item(self, key, value)
#    4314             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4315             refs = None
# -> 4317 self._set_item_mgr(key, value, refs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4267, in DataFrame._set_item_mgr(self, key, value, refs)
#    4264     loc = self._info_axis.get_loc(key)
#    4265 except KeyError:
#    4266     # This item wasn't present, just insert at end
# -> 4267     self._mgr.insert(len(self._info_axis), key, value, refs)
#    4268 else:
#    4269     self._iset_item_mgr(loc, value, refs=refs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1351, in BlockManager.insert(self, loc, item, value, refs)
#    1347 self.blocks += (block,)
#    1349 self._known_consolidated = False
# -> 1351 if sum(not block.is_extension for block in self.blocks) > 100:
#    1352     warnings.warn(
#    1353         "DataFrame is highly fragmented.  This is usually the result "
#    1354         "of calling `frame.insert` many times, which has poor performance.  "
#    (...)
#    1358         stacklevel=find_stack_level(),
#    1359     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1351, in <genexpr>(.0)
#    1347 self.blocks += (block,)
#    1349 self._known_consolidated = False
# -> 1351 if sum(not block.is_extension for block in self.blocks) > 100:
#    1352     warnings.warn(
#    1353         "DataFrame is highly fragmented.  This is usually the result "
#    1354         "of calling `frame.insert` many times, which has poor performance.  "
#    (...)
#    1358         stacklevel=find_stack_level(),
#    1359     )
#
# KeyboardInterrupt:
